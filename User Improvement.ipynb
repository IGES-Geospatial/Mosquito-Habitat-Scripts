# %% [markdown]
# # User improvement
#
# This script groups entries made by users together and orders them from oldest to newest. This can facillitate future research exploring how citizen scientists improve over time.

# %% [markdown]
# # Downloading Data Procedure:
#
# ## Use:
# Run the following cell if you would like to get data from the GLOBE API
#
# ## Procedure
# Downloading data from the API follows these steps:
# - Request the non GEOJSON data from the GLOBE API
# - Get the results from the JSON and pass it into a pandas dataframe
# - Unpack the "data" entry
# - Merge the data onto the original dataframe
# - Remove the "data" entry from the original dataframe

# %%
import pandas as pd
import requests

start_date = "2017-05-29"
end_date = "2020-05-31"
url = f"https://api.globe.gov/search/v1/measurement/protocol/measureddate/?protocols=mosquito_habitat_mapper&startdate={start_date}&enddate={end_date}&geojson=FALSE&sample=FALSE"

# downloads data from the GLOBE API
response = requests.get(url)

# Converts data into a useable dataframe
data = response.json()["results"]
        
temp_data_df = pd.DataFrame(data)

temp_data_df["data"]
data_df = pd.DataFrame(temp_data_df["data"].to_dict())
data_df = data_df.transpose()
temp_data_df = temp_data_df.join(data_df)
temp_data_df.drop(["data"], axis=1, inplace = True)
temp_data_df
# Out:
#                       protocol measuredDate           createDate  \
# 0      mosquito_habitat_mapper   2018-11-25  2020-01-25T18:09:52
# 1      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 2      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 3      mosquito_habitat_mapper   2019-05-29  2020-01-25T18:29:36
# 4      mosquito_habitat_mapper   2019-08-04  2020-01-25T18:45:20
# ...                        ...          ...                  ...
# 22449  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 22450  mosquito_habitat_mapper   2020-05-29  2020-06-03T07:30:03
# 22451  mosquito_habitat_mapper   2020-05-06  2020-07-14T08:40:05
# 22452  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
# 22453  mosquito_habitat_mapper   2020-01-29  2020-07-23T07:13:04
#
#                 updateDate          publishDate  organizationId  \
# 0      2020-01-25T18:09:52  2020-02-14T20:29:11      13063641.0
# 1      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 2      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 3      2020-01-25T18:29:36  2020-03-20T22:19:48      13063641.0
# 4      2020-01-25T18:45:20  2020-03-20T22:19:48      13063641.0
# ...                    ...                  ...             ...
# 22449  2020-05-30T19:30:02  2020-08-26T21:23:29      14054356.0
# 22450  2020-06-03T16:15:20  2020-08-26T21:23:29      19841715.0
# 22451  2020-07-14T13:40:07  2020-08-26T21:23:29      18306968.0
# 22452  2020-07-18T23:35:02  2020-08-26T21:23:29      14054356.0
# 22453  2020-07-23T07:13:04  2020-08-26T21:23:29        217639.0
#
#                          organizationName  siteId     siteName    countryName  \
# 0                   GPM Satellite Mission   35785  18SUJ105472  United States
# 1                   GPM Satellite Mission   35785  18SUJ105472  United States
# 2                   GPM Satellite Mission   35785  18SUJ105472  United States
# 3                   GPM Satellite Mission   35785  18SUJ105472  United States
# 4                   GPM Satellite Mission   35785  18SUJ105472  United States
# ...                                   ...     ...          ...            ...
# 22449                     lycee Thilmakha  200580  28PCB553673        Senegal
# 22450          Madagascar Citizen Science  201123  38KQE645064           None
# 22451  Taiwan Partnership Citizen Science  208771  51RUH399684           None
# 22452                     lycee Thilmakha  209660  28PDB055429        Senegal
# 22453  Suranaree University of Technology  210372  47PNK984553       Thailand
#
#        ... mosquitohabitatmapperComments  mosquitohabitatmapperMosquitoPupae  \
# 0      ...                          None                               False
# 1      ...                          None                               False
# 2      ...                          None                               False
# 3      ...                          None                               False
# 4      ...                          None                               False
# ...    ...                           ...                                 ...
# 22449  ...                          None                                True
# 22450  ...                          None                               False
# 22451  ...                          None                                True
# 22452  ...                          None                                True
# 22453  ...                          None                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0      https://data.globe.gov/system/photos/2018/11/2...
# 1      https://data.globe.gov/system/photos/2019/04/0...
# 2      https://data.globe.gov/system/photos/2019/04/0...
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4      https://data.globe.gov/system/photos/2019/08/0...
# ...                                                  ...
# 22449  https://data.globe.gov/system/photos/2020/05/3...
# 22450  https://data.globe.gov/system/photos/2020/05/2...
# 22451                                               None
# 22452  https://data.globe.gov/system/photos/2020/05/3...
# 22453                                               None
#
#        mosquitohabitatmapperDataSource  \
# 0                   GLOBE Observer App
# 1                   GLOBE Observer App
# 2                   GLOBE Observer App
# 3                   GLOBE Observer App
# 4                   GLOBE Observer App
# ...                                ...
# 22449               GLOBE Observer App
# 22450               GLOBE Observer App
# 22451               GLOBE Observer App
# 22452               GLOBE Observer App
# 22453               GLOBE Observer App
#
#              mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4                                                   None
# ...                                                  ...
# 22449  https://data.globe.gov/system/photos/2020/05/3...
# 22450                                               None
# 22451  https://data.globe.gov/system/photos/2020/05/0...
# 22452                                               None
# 22453                                               None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                      39.2538
# 1                                      39.2535
# 2                                      39.2536
# 3                                      39.2542
# 4                                      39.2536
# ...                                        ...
# 22449                                  15.0777
# 22450                                 -18.9168
# 22451                                  25.0235
# 22452                                  14.8591
# 22453                                    8.642
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 0                                       None
# 1                                   identify
# 2                                   identify
# 3                     identify-siphon-pecten
# 4                                   identify
# ...                                      ...
# 22449                  identify-siphon-shape
# 22450                               identify
# 22451                    identify-basal-tuft
# 22452                    identify-aedes-tuft
# 22453                    identify-photo-prep
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                    container: artificial
# 1                    container: artificial
# 2                    container: artificial
# 3                    container: artificial
# 4                    container: artificial
# ...                                    ...
# 22449                container: artificial
# 22450                container: artificial
# 22451                container: artificial
# 22452                container: artificial
# 22453                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                             5188
# 1                                            10365
# 2                                            10360
# 3                                            12424
# 4                                            14822
# ...                                            ...
# 22449                                        22775
# 22450                                        22806
# 22451                                        24654
# 22452                                        24880
# 22453                                        25049
#
#       mosquitohabitatmapperMeasurementLongitude
# 0                                      -77.1959
# 1                                       -77.196
# 2                                      -77.1956
# 3                                      -77.1962
# 4                                      -77.1957
# ...                                         ...
# 22449                                  -16.3463
# 22450                                   47.5121
# 22451                                   121.413
# 22452                                  -15.8784
# 22453                                   99.8951
#
# [22454 rows x 38 columns]

# %% [markdown]
# # Sorting/Grouping Procedure:
#
# - Groups entries with the same User ID
# - Creates a list of the UserID's and the size of the groups
# - Sorts the list by size of group in descending order
# - Iterates through the list of sorted groups and takes each group, sorts the
# observations by User ID, and then adds it to the final data frame
#
# Result: a observations with entries that share the same user being grouped
# into the same part of the spreadsheet. These groups also show the observations
# made by the user from oldest to latest. This will allow people to analyze the
# improvement of certain users over time.

# %%
# creates groups by similar userID
groups = temp_data_df.groupby("mosquitohabitatmapperUserid")

# %%
# creates a list of users (sorted by amt of entries)
gb = groups.size()
gb = gb.sort_values(ascending = False)
gb = gb.reset_index()
gb
# Out:
#       mosquitohabitatmapperUserid    0
# 0                        51045191  739
# 1                        50985322  565
# 2                         5284745  456
# 3                        51046601  408
# 4                        21748177  374
# ...                           ...  ...
# 4899                     52560189    1
# 4900                     52560018    1
# 4901                     52559362    1
# 4902                     52559352    1
# 4903                        11086    1
#
# [4904 rows x 2 columns]

# %%
# for each of the userID's, it sorts their entries (oldest - newest) and adds to master dataframe
final_df = pd.DataFrame()
for userID in gb["mosquitohabitatmapperUserid"]:
    df = groups.get_group(userID).sort_values("measuredDate")
    final_df = final_df.append(df, ignore_index = True)

final_df
# Out:
#                       protocol measuredDate           createDate  \
# 0      mosquito_habitat_mapper   2018-12-15  2020-01-25T18:11:17
# 1      mosquito_habitat_mapper   2018-12-20  2020-01-25T18:11:17
# 2      mosquito_habitat_mapper   2019-02-20  2020-01-25T18:16:36
# 3      mosquito_habitat_mapper   2019-02-24  2020-01-25T18:16:36
# 4      mosquito_habitat_mapper   2019-03-02  2020-01-25T18:18:54
# ...                        ...          ...                  ...
# 22449  mosquito_habitat_mapper   2019-02-23  2020-01-25T18:16:36
# 22450  mosquito_habitat_mapper   2019-02-23  2020-01-25T18:16:36
# 22451  mosquito_habitat_mapper   2019-02-23  2020-01-25T18:16:36
# 22452  mosquito_habitat_mapper   2019-02-23  2020-01-25T18:16:36
# 22453  mosquito_habitat_mapper   2017-08-01  2020-01-25T17:36:55
#
#                 updateDate          publishDate  organizationId  \
# 0      2020-01-25T18:11:17  2020-02-14T20:29:11      19383352.0
# 1      2020-01-25T18:11:17  2020-02-14T20:29:11      19383352.0
# 2      2020-01-25T18:16:36  2020-03-20T22:19:48             NaN
# 3      2020-01-25T18:16:36  2020-03-20T22:19:48             NaN
# 4      2020-01-25T18:18:54  2020-03-20T22:19:48             NaN
# ...                    ...                  ...             ...
# 22449  2020-01-25T18:16:36  2020-03-20T22:19:48      17615655.0
# 22450  2020-01-25T18:16:36  2020-03-20T22:19:48      17615655.0
# 22451  2020-01-25T18:16:36  2020-03-20T22:19:48      17615655.0
# 22452  2020-01-25T18:16:36  2020-03-20T22:19:48      17615655.0
# 22453  2020-01-25T17:36:55  2020-02-14T20:29:11      26289279.0
#
#                 organizationName  siteId     siteName    countryName  ...  \
# 0        Senegal Citizen Science  143292  28PCB659632           None  ...
# 1        Senegal Citizen Science  143292  28PCB659632           None  ...
# 2                           None  146141  28PCB659632           None  ...
# 3                           None  146141  28PCB659632           None  ...
# 4                           None  146141  28PCB659632           None  ...
# ...                          ...     ...          ...            ...  ...
# 22449   Thailand Citizen Science  146285  47QQV895620           None  ...
# 22450   Thailand Citizen Science  146285  47QQV895620           None  ...
# 22451   Thailand Citizen Science  146286  47QQV894619           None  ...
# 22452   Thailand Citizen Science  146285  47QQV895620           None  ...
# 22453  GLOBE Annual Meeting 2017   55293  18TXL726774  United States  ...
#
#       mosquitohabitatmapperComments  mosquitohabitatmapperMosquitoPupae  \
# 0                              None                                True
# 1                              None                               False
# 2                              None                                True
# 3                              None                                True
# 4                              None                                True
# ...                             ...                                 ...
# 22449                          None                               False
# 22450                          None                               False
# 22451                          None                                True
# 22452                          None                                True
# 22453                          None                                None
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0      https://data.globe.gov/system/photos/2018/12/1...
# 1      https://data.globe.gov/system/photos/2018/12/2...
# 2      https://data.globe.gov/system/photos/2019/02/2...
# 3      https://data.globe.gov/system/photos/2019/02/2...
# 4      https://data.globe.gov/system/photos/2019/03/0...
# ...                                                  ...
# 22449  https://data.globe.gov/system/photos/2019/02/2...
# 22450  https://data.globe.gov/system/photos/2019/02/2...
# 22451  https://data.globe.gov/system/photos/2019/02/2...
# 22452  https://data.globe.gov/system/photos/2019/02/2...
# 22453  https://data.globe.gov/system/photos/2017/08/0...
#
#        mosquitohabitatmapperDataSource  \
# 0                   GLOBE Observer App
# 1                   GLOBE Observer App
# 2                   GLOBE Observer App
# 3                   GLOBE Observer App
# 4                   GLOBE Observer App
# ...                                ...
# 22449               GLOBE Observer App
# 22450               GLOBE Observer App
# 22451               GLOBE Observer App
# 22452               GLOBE Observer App
# 22453               GLOBE Observer App
#
#              mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0      https://data.globe.gov/system/photos/2018/12/1...
# 1      https://data.globe.gov/system/photos/2018/12/2...
# 2      https://data.globe.gov/system/photos/2019/02/2...
# 3      https://data.globe.gov/system/photos/2019/02/2...
# 4      https://data.globe.gov/system/photos/2019/03/0...
# ...                                                  ...
# 22449  https://data.globe.gov/system/photos/2019/02/2...
# 22450  https://data.globe.gov/system/photos/2019/02/2...
# 22451  https://data.globe.gov/system/photos/2019/02/2...
# 22452  https://data.globe.gov/system/photos/2019/02/2...
# 22453                                               None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                       15.041
# 1                                      15.0408
# 2                                      15.0407
# 3                                       15.041
# 4                                       15.041
# ...                                        ...
# 22449                                  17.7268
# 22450                                  17.7267
# 22451                                  17.7261
# 22452                                  17.7267
# 22453                                  41.3296
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 0                      identify-siphon-shape
# 1                      identify-siphon-shape
# 2                      identify-siphon-shape
# 3                      identify-siphon-shape
# 4                      identify-siphon-shape
# ...                                      ...
# 22449                    identify-basal-tuft
# 22450                  identify-siphon-shape
# 22451               identify-saddle-complete
# 22452               identify-saddle-complete
# 22453                                   None
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                    container: artificial
# 1                    container: artificial
# 2                    container: artificial
# 3                    container: artificial
# 4                    container: artificial
# ...                                    ...
# 22449                container: artificial
# 22450               still: lake/pond/swamp
# 22451                container: artificial
# 22452                container: artificial
# 22453               still: lake/pond/swamp
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                             6128
# 1                                             6147
# 2                                             7635
# 3                                             8009
# 4                                             8066
# ...                                            ...
# 22449                                         7758
# 22450                                         7732
# 22451                                         7683
# 22452                                         7682
# 22453                                          201
#
#       mosquitohabitatmapperMeasurementLongitude
# 0                                      -16.2473
# 1                                      -16.2474
# 2                                      -16.2473
# 3                                      -16.2473
# 4                                      -16.2473
# ...                                         ...
# 22449                                    101.73
# 22450                                    101.73
# 22451                                    101.73
# 22452                                    101.73
# 22453                                  -72.9375
#
# [22454 rows x 38 columns]

# %%
# outputs to file
final_df.to_csv("User_List.csv")
