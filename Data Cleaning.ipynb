# %% [markdown]
# # API Downloading Data Procedure:
#
# Downloading data follows these steps:
# - Request the non GEOJSON data from the GLOBE API
# - Get the results from the JSON and pass it into a pandas dataframe
# - Unpack the "data" entry
# - Merge the data onto the original dataframe
# - Remove the "data" entry from the original dataframe

# %%
import pandas as pd
import requests

start_date = "2017-05-29"
end_date = "2020-05-31"
url = f"https://api.globe.gov/search/v1/measurement/protocol/measureddate/?protocols=mosquito_habitat_mapper&startdate={start_date}&enddate={end_date}&geojson=FALSE&sample=FALSE"

# downloads data from the GLOBE API
response = requests.get(url)
results = response.json()["results"]

df = pd.DataFrame(results)

#Expand the 'data' column by listing the contents and passing as a new dataframe
df = pd.concat([df, pd.DataFrame(list(df['data']))], axis=1)

#Drop the previously nested data column
df = df.drop('data', 1)



# display the dataframe
df
# Out:
#                       protocol measuredDate           createDate  \
# 0      mosquito_habitat_mapper   2018-11-25  2020-01-25T18:09:52
# 1      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 2      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 3      mosquito_habitat_mapper   2019-05-29  2020-01-25T18:29:36
# 4      mosquito_habitat_mapper   2019-08-04  2020-01-25T18:45:20
# ...                        ...          ...                  ...
# 22452  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 22453  mosquito_habitat_mapper   2020-05-29  2020-06-03T07:30:03
# 22454  mosquito_habitat_mapper   2020-05-06  2020-07-14T08:40:05
# 22455  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
# 22456  mosquito_habitat_mapper   2020-01-29  2020-07-23T07:13:04
#
#                 updateDate          publishDate  organizationId  \
# 0      2020-01-25T18:09:52  2020-02-14T20:29:11      13063641.0
# 1      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 2      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 3      2020-01-25T18:29:36  2020-03-20T22:19:48      13063641.0
# 4      2020-01-25T18:45:20  2020-03-20T22:19:48      13063641.0
# ...                    ...                  ...             ...
# 22452  2020-05-30T19:30:02  2020-10-26T21:48:32      14054356.0
# 22453  2020-06-03T16:15:20  2020-10-26T21:48:32      19841715.0
# 22454  2020-07-14T13:40:07  2020-10-26T21:48:32      18306968.0
# 22455  2020-07-18T23:35:02  2020-10-26T21:48:32      14054356.0
# 22456  2020-07-23T07:13:04  2020-10-26T21:48:32        217639.0
#
#                          organizationName  siteId     siteName    countryName  \
# 0                   GPM Satellite Mission   35785  18SUJ105472  United States
# 1                   GPM Satellite Mission   35785  18SUJ105472  United States
# 2                   GPM Satellite Mission   35785  18SUJ105472  United States
# 3                   GPM Satellite Mission   35785  18SUJ105472  United States
# 4                   GPM Satellite Mission   35785  18SUJ105472  United States
# ...                                   ...     ...          ...            ...
# 22452                     lycee Thilmakha  200580  28PCB553673        Senegal
# 22453          Madagascar Citizen Science  201123  38KQE645064           None
# 22454  Taiwan Partnership Citizen Science  208771  51RUH399684           None
# 22455                     lycee Thilmakha  209660  28PDB055429        Senegal
# 22456  Suranaree University of Technology  210372  47PNK984553       Thailand
#
#        ... mosquitohabitatmapperComments  mosquitohabitatmapperMosquitoPupae  \
# 0      ...                          None                               False
# 1      ...                          None                               False
# 2      ...                          None                               False
# 3      ...                          None                               False
# 4      ...                          None                               False
# ...    ...                           ...                                 ...
# 22452  ...                          None                                True
# 22453  ...                          None                               False
# 22454  ...                          None                                True
# 22455  ...                          None                                True
# 22456  ...                          None                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0      https://data.globe.gov/system/photos/2018/11/2...
# 1      https://data.globe.gov/system/photos/2019/04/0...
# 2      https://data.globe.gov/system/photos/2019/04/0...
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4      https://data.globe.gov/system/photos/2019/08/0...
# ...                                                  ...
# 22452  https://data.globe.gov/system/photos/2020/05/3...
# 22453  https://data.globe.gov/system/photos/2020/05/2...
# 22454                                               None
# 22455  https://data.globe.gov/system/photos/2020/05/3...
# 22456                                               None
#
#        mosquitohabitatmapperDataSource  \
# 0                   GLOBE Observer App
# 1                   GLOBE Observer App
# 2                   GLOBE Observer App
# 3                   GLOBE Observer App
# 4                   GLOBE Observer App
# ...                                ...
# 22452               GLOBE Observer App
# 22453               GLOBE Observer App
# 22454               GLOBE Observer App
# 22455               GLOBE Observer App
# 22456               GLOBE Observer App
#
#              mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4                                                   None
# ...                                                  ...
# 22452  https://data.globe.gov/system/photos/2020/05/3...
# 22453                                               None
# 22454  https://data.globe.gov/system/photos/2020/05/0...
# 22455                                               None
# 22456                                               None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                      39.2538
# 1                                      39.2535
# 2                                      39.2536
# 3                                      39.2542
# 4                                      39.2536
# ...                                        ...
# 22452                                  15.0777
# 22453                                 -18.9168
# 22454                                  25.0235
# 22455                                  14.8591
# 22456                                   8.6420
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 0                                       None
# 1                                   identify
# 2                                   identify
# 3                     identify-siphon-pecten
# 4                                   identify
# ...                                      ...
# 22452                 identify-siphon-pecten
# 22453                               identify
# 22454                    identify-basal-tuft
# 22455                    identify-aedes-tuft
# 22456                    identify-photo-prep
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                    container: artificial
# 1                    container: artificial
# 2                    container: artificial
# 3                    container: artificial
# 4                    container: artificial
# ...                                    ...
# 22452                container: artificial
# 22453                container: artificial
# 22454                container: artificial
# 22455                container: artificial
# 22456                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                             5188
# 1                                            10365
# 2                                            10360
# 3                                            12424
# 4                                            14822
# ...                                            ...
# 22452                                        22779
# 22453                                        22806
# 22454                                        24654
# 22455                                        24880
# 22456                                        25049
#
#        mosquitohabitatmapperMeasurementLongitude
# 0                                       -77.1959
# 1                                       -77.1960
# 2                                       -77.1956
# 3                                       -77.1962
# 4                                       -77.1957
# ...                                          ...
# 22452                                   -16.3463
# 22453                                    47.5121
# 22454                                   121.4134
# 22455                                   -15.8784
# 22456                                    99.8951
#
# [22457 rows x 38 columns]

# %% [markdown]
# # CSV Downloading
#
# This cell allows for the option of using mosquito mapper data from CSV Files.
#
# This enables an analysis of different subsets of the total mosquito mapper data (this will overwrite data downloaded from the API).

# %%
filename = "Africa.csv"
df = pd.read_csv(filename)
df
# Out:
#       Unnamed: 0                 protocol measuredDate           createDate  \
# 0            594  mosquito_habitat_mapper   2017-07-05  2020-01-25T17:36:06
# 1            635  mosquito_habitat_mapper   2017-07-06  2020-01-25T17:36:06
# 2            640  mosquito_habitat_mapper   2017-07-07  2020-01-25T17:36:06
# 3           2618  mosquito_habitat_mapper   2017-08-01  2020-01-25T17:36:55
# 4           3410  mosquito_habitat_mapper   2018-09-08  2020-01-25T18:05:43
# ...          ...                      ...          ...                  ...
# 4537       22446  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 4538       22447  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 4539       22448  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 4540       22449  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 4541       22452  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
#
#                updateDate          publishDate  organizationId  \
# 0     2020-01-25T17:36:06  2020-02-14T20:29:11      23351884.0
# 1     2020-01-25T17:36:06  2020-02-14T20:29:11      24610401.0
# 2     2020-01-25T17:36:06  2020-02-14T20:29:11      24610401.0
# 3     2020-01-25T17:36:55  2020-02-14T20:29:11        236305.0
# 4     2020-01-25T18:05:43  2020-02-14T20:29:11        127300.0
# ...                   ...                  ...             ...
# 4537  2020-05-30T19:30:02  2020-09-05T21:23:09      14054356.0
# 4538  2020-05-30T19:30:02  2020-09-05T21:23:09      14054356.0
# 4539  2020-05-30T19:30:02  2020-09-05T21:23:09      14054356.0
# 4540  2020-05-30T19:30:02  2020-09-05T21:23:09      14054356.0
# 4541  2020-07-18T23:35:02  2020-09-05T21:23:09      14054356.0
#
#                                organizationName  siteId     siteName  ...  \
# 0     Twene Amanfo Senior High/Technical School   53048  30NWP747107  ...
# 1                               Terre Rouge SSS   53208  40KEC556754  ...
# 2                               Terre Rouge SSS   53238  40KEC557756  ...
# 3                      Kabojja Secondary School   99016  18TXL725776  ...
# 4                        Indwe Secondary School  106855  34HFH012220  ...
# ...                                         ...     ...          ...  ...
# 4537                            lycee Thilmakha  200580  28PCB553673  ...
# 4538                            lycee Thilmakha  200580  28PCB553673  ...
# 4539                            lycee Thilmakha  200580  28PCB553673  ...
# 4540                            lycee Thilmakha  200580  28PCB553673  ...
# 4541                            lycee Thilmakha  209660  28PDB055429  ...
#
#      mosquitohabitatmapperComments mosquitohabitatmapperMosquitoPupae  \
# 0                              NaN                                NaN
# 1                              NaN                               True
# 2                              NaN                               True
# 3                              NaN                               True
# 4                              NaN                                NaN
# ...                            ...                                ...
# 4537                           NaN                               True
# 4538                           NaN                               True
# 4539                           NaN                               True
# 4540                           NaN                               True
# 4541                           NaN                               True
#
#               mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0     https://data.globe.gov/system/photos/2017/07/0...
# 1                                                   NaN
# 2                                                   NaN
# 3     https://data.globe.gov/system/photos/2017/08/0...
# 4     https://data.globe.gov/system/photos/2018/09/0...
# ...                                                 ...
# 4537  https://data.globe.gov/system/photos/2020/05/3...
# 4538  https://data.globe.gov/system/photos/2020/05/3...
# 4539  https://data.globe.gov/system/photos/2020/05/3...
# 4540  https://data.globe.gov/system/photos/2020/05/3...
# 4541  https://data.globe.gov/system/photos/2020/05/3...
#
#       mosquitohabitatmapperDataSource  \
# 0                  GLOBE Observer App
# 1                  GLOBE Observer App
# 2                  GLOBE Observer App
# 3                  GLOBE Observer App
# 4                  GLOBE Observer App
# ...                               ...
# 4537               GLOBE Observer App
# 4538               GLOBE Observer App
# 4539               GLOBE Observer App
# 4540               GLOBE Observer App
# 4541               GLOBE Observer App
#
#             mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   NaN
# 1     https://data.globe.gov/system/photos/2017/07/0...
# 2     https://data.globe.gov/system/photos/2017/07/0...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4537  https://data.globe.gov/system/photos/2020/05/3...
# 4538  https://data.globe.gov/system/photos/2020/05/3...
# 4539  https://data.globe.gov/system/photos/2020/05/3...
# 4540  https://data.globe.gov/system/photos/2020/05/3...
# 4541                                                NaN
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                     7.333747
# 1                                   -20.117747
# 2                                   -20.115937
# 3                                    41.331432
# 4                                   -34.137100
# ...                                        ...
# 4537                                 15.077800
# 4538                                 15.077700
# 4539                                 15.077700
# 4540                                 15.077700
# 4541                                 14.859100
#
#      mosquitohabitatmapperLastIdentifyStage  \
# 0                                       NaN
# 1                     identify-siphon-shape
# 2                        identify-no-siphon
# 3                                  identify
# 4                                       NaN
# ...                                     ...
# 4537                  identify-siphon-shape
# 4538                  identify-siphon-shape
# 4539                 identify-siphon-pecten
# 4540                  identify-siphon-shape
# 4541                    identify-aedes-tuft
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                   still: lake/pond/swamp
# 1                   still: lake/pond/swamp
# 2                    container: artificial
# 3                   still: lake/pond/swamp
# 4                    container: artificial
# ...                                    ...
# 4537                 container: artificial
# 4538                 container: artificial
# 4539                 container: artificial
# 4540                 container: artificial
# 4541                 container: artificial
#
#      mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                             137
# 1                                             100
# 2                                             104
# 3                                             935
# 4                                            4401
# ...                                           ...
# 4537                                        22774
# 4538                                        22775
# 4539                                        22779
# 4540                                        22776
# 4541                                        24880
#
#      mosquitohabitatmapperMeasurementLongitude
# 0                                    -2.323205
# 1                                    57.531913
# 2                                    57.532863
# 3                                   -72.938605
# 4                                    22.098000
# ...                                        ...
# 4537                                -16.346300
# 4538                                -16.346300
# 4539                                -16.346300
# 4540                                -16.346300
# 4541                                -15.878400
#
# [4542 rows x 39 columns]

# %% [markdown]
# # GeoLocational Data Cleaning Procedure:
# Here are the conditions in which the data is removed:
# - The Site Latitude and Longitude match the ones measured by the GPS
# - The GPS Measurements are integers

# %%
import numpy as np

def geolocational_filter(gps_lat, gps_lon, recorded_lat, recorded_lon):
    return ((recorded_lat == gps_lat and 
        recorded_lon == gps_lon) or
         gps_lat == int(gps_lat) or
         gps_lon == int(gps_lon)
        )

vectorized_filter = np.vectorize(geolocational_filter)
bad_data = vectorized_filter(df["mosquitohabitatmapperMeasurementLatitude"].to_numpy(),
                             df["mosquitohabitatmapperMeasurementLongitude"].to_numpy(),
                             df["latitude"].to_numpy(),
                             df["longitude"].to_numpy()
                            )
df = df[~bad_data]
df = df.reset_index().drop(["index"], axis = 1)
# displaying the dataframe
df
# Out:
#                       protocol measuredDate           createDate  \
# 0      mosquito_habitat_mapper   2018-11-25  2020-01-25T18:09:52
# 1      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 2      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 3      mosquito_habitat_mapper   2019-05-29  2020-01-25T18:29:36
# 4      mosquito_habitat_mapper   2019-08-04  2020-01-25T18:45:20
# ...                        ...          ...                  ...
# 19277  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 19278  mosquito_habitat_mapper   2020-05-29  2020-06-03T07:30:03
# 19279  mosquito_habitat_mapper   2020-05-06  2020-07-14T08:40:05
# 19280  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
# 19281  mosquito_habitat_mapper   2020-01-29  2020-07-23T07:13:04
#
#                 updateDate          publishDate  organizationId  \
# 0      2020-01-25T18:09:52  2020-02-14T20:29:11      13063641.0
# 1      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 2      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 3      2020-01-25T18:29:36  2020-03-20T22:19:48      13063641.0
# 4      2020-01-25T18:45:20  2020-03-20T22:19:48      13063641.0
# ...                    ...                  ...             ...
# 19277  2020-05-30T19:30:02  2020-10-26T21:48:32      14054356.0
# 19278  2020-06-03T16:15:20  2020-10-26T21:48:32      19841715.0
# 19279  2020-07-14T13:40:07  2020-10-26T21:48:32      18306968.0
# 19280  2020-07-18T23:35:02  2020-10-26T21:48:32      14054356.0
# 19281  2020-07-23T07:13:04  2020-10-26T21:48:32        217639.0
#
#                          organizationName  siteId     siteName    countryName  \
# 0                   GPM Satellite Mission   35785  18SUJ105472  United States
# 1                   GPM Satellite Mission   35785  18SUJ105472  United States
# 2                   GPM Satellite Mission   35785  18SUJ105472  United States
# 3                   GPM Satellite Mission   35785  18SUJ105472  United States
# 4                   GPM Satellite Mission   35785  18SUJ105472  United States
# ...                                   ...     ...          ...            ...
# 19277                     lycee Thilmakha  200580  28PCB553673        Senegal
# 19278          Madagascar Citizen Science  201123  38KQE645064           None
# 19279  Taiwan Partnership Citizen Science  208771  51RUH399684           None
# 19280                     lycee Thilmakha  209660  28PDB055429        Senegal
# 19281  Suranaree University of Technology  210372  47PNK984553       Thailand
#
#        ... mosquitohabitatmapperComments  mosquitohabitatmapperMosquitoPupae  \
# 0      ...                          None                               False
# 1      ...                          None                               False
# 2      ...                          None                               False
# 3      ...                          None                               False
# 4      ...                          None                               False
# ...    ...                           ...                                 ...
# 19277  ...                          None                                True
# 19278  ...                          None                               False
# 19279  ...                          None                                True
# 19280  ...                          None                                True
# 19281  ...                          None                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0      https://data.globe.gov/system/photos/2018/11/2...
# 1      https://data.globe.gov/system/photos/2019/04/0...
# 2      https://data.globe.gov/system/photos/2019/04/0...
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4      https://data.globe.gov/system/photos/2019/08/0...
# ...                                                  ...
# 19277  https://data.globe.gov/system/photos/2020/05/3...
# 19278  https://data.globe.gov/system/photos/2020/05/2...
# 19279                                               None
# 19280  https://data.globe.gov/system/photos/2020/05/3...
# 19281                                               None
#
#        mosquitohabitatmapperDataSource  \
# 0                   GLOBE Observer App
# 1                   GLOBE Observer App
# 2                   GLOBE Observer App
# 3                   GLOBE Observer App
# 4                   GLOBE Observer App
# ...                                ...
# 19277               GLOBE Observer App
# 19278               GLOBE Observer App
# 19279               GLOBE Observer App
# 19280               GLOBE Observer App
# 19281               GLOBE Observer App
#
#              mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4                                                   None
# ...                                                  ...
# 19277  https://data.globe.gov/system/photos/2020/05/3...
# 19278                                               None
# 19279  https://data.globe.gov/system/photos/2020/05/0...
# 19280                                               None
# 19281                                               None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                      39.2538
# 1                                      39.2535
# 2                                      39.2536
# 3                                      39.2542
# 4                                      39.2536
# ...                                        ...
# 19277                                  15.0777
# 19278                                 -18.9168
# 19279                                  25.0235
# 19280                                  14.8591
# 19281                                   8.6420
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 0                                       None
# 1                                   identify
# 2                                   identify
# 3                     identify-siphon-pecten
# 4                                   identify
# ...                                      ...
# 19277                 identify-siphon-pecten
# 19278                               identify
# 19279                    identify-basal-tuft
# 19280                    identify-aedes-tuft
# 19281                    identify-photo-prep
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                    container: artificial
# 1                    container: artificial
# 2                    container: artificial
# 3                    container: artificial
# 4                    container: artificial
# ...                                    ...
# 19277                container: artificial
# 19278                container: artificial
# 19279                container: artificial
# 19280                container: artificial
# 19281                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                             5188
# 1                                            10365
# 2                                            10360
# 3                                            12424
# 4                                            14822
# ...                                            ...
# 19277                                        22779
# 19278                                        22806
# 19279                                        24654
# 19280                                        24880
# 19281                                        25049
#
#        mosquitohabitatmapperMeasurementLongitude
# 0                                       -77.1959
# 1                                       -77.1960
# 2                                       -77.1956
# 3                                       -77.1962
# 4                                       -77.1957
# ...                                          ...
# 19277                                   -16.3463
# 19278                                    47.5121
# 19279                                   121.4134
# 19280                                   -15.8784
# 19281                                    99.8951
#
# [19282 rows x 38 columns]

# %%
# writes the filtered data to a csv
df.to_csv("Geolocation.csv")

# %% [markdown]
# # Suspected Training Event Removal
#
# The procedure that is used is as follows:
# - Mosquito Entries that share the same measured date, site latitude, site longitude, siteName, and water source are grouped together
# - These groups are then filtered resulting in identifying groups of a size greater than a specified threshold.
# - Then these identified groups are removed from the overall dataframe
# - The dataframe containing the groups and the clean dataframe are then written into csv files.

# %% [markdown]
# ## Threshold Variable
#
# The threshold variable is the minimum number of duplicate entries (exclusive) that are needed for the the group of entries to be classified as an event.
#
# Set the threshold value and then run the following cells

# %%
threshold = 10

# %%
# groups / filters suspected events
suspect_df = df.groupby(by=['measuredDate','latitude','mosquitohabitatmapperWaterSource','siteName','longitude']).filter(lambda x: len(x) > threshold)

# writes the entries to a CSV
suspect_df.to_csv("Possible Events.csv")       

# displays the suspected entries
suspect_df
# Out:
#                       protocol measuredDate           createDate  \
# 469    mosquito_habitat_mapper   2018-08-17  2020-01-25T18:02:43
# 473    mosquito_habitat_mapper   2018-08-17  2020-01-25T18:02:43
# 475    mosquito_habitat_mapper   2018-08-17  2020-01-25T18:02:43
# 476    mosquito_habitat_mapper   2018-08-17  2020-01-25T18:02:43
# 481    mosquito_habitat_mapper   2018-08-17  2020-01-25T18:02:43
# ...                        ...          ...                  ...
# 19152  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
# 19153  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
# 19154  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
# 19157  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
# 19160  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
#
#                 updateDate          publishDate  organizationId  \
# 469    2020-01-25T18:02:43  2020-02-14T20:29:11      17615655.0
# 473    2020-01-25T18:02:43  2020-02-14T20:29:11      17615655.0
# 475    2020-01-25T18:02:43  2020-02-14T20:29:11      17615655.0
# 476    2020-01-25T18:02:43  2020-02-14T20:29:11      17615655.0
# 481    2020-01-25T18:02:43  2020-02-14T20:29:11      17615655.0
# ...                    ...                  ...             ...
# 19152  2020-04-20T07:31:25  2020-10-26T21:48:32      17615655.0
# 19153  2020-04-20T07:31:25  2020-10-26T21:48:32      17615655.0
# 19154  2020-04-20T07:31:25  2020-10-26T21:48:32      17615655.0
# 19157  2020-04-20T07:31:25  2020-10-26T21:48:32      17615655.0
# 19160  2020-04-20T07:31:25  2020-10-26T21:48:32      17615655.0
#
#                organizationName  siteId     siteName countryName  ...  \
# 469    Thailand Citizen Science   97680  47PNK988555        None  ...
# 473    Thailand Citizen Science   97680  47PNK988555        None  ...
# 475    Thailand Citizen Science   97680  47PNK988555        None  ...
# 476    Thailand Citizen Science   97680  47PNK988555        None  ...
# 481    Thailand Citizen Science   97680  47PNK988555        None  ...
# ...                         ...     ...          ...         ...  ...
# 19152  Thailand Citizen Science  196380  47QMB636059        None  ...
# 19153  Thailand Citizen Science  196380  47QMB636059        None  ...
# 19154  Thailand Citizen Science  196380  47QMB636059        None  ...
# 19157  Thailand Citizen Science  196380  47QMB636059        None  ...
# 19160  Thailand Citizen Science  196380  47QMB636059        None  ...
#
#       mosquitohabitatmapperComments  mosquitohabitatmapperMosquitoPupae  \
# 469                            None                                None
# 473                            None                                None
# 475                            None                                None
# 476                            None                                None
# 481                            None                                None
# ...                             ...                                 ...
# 19152                          None                               False
# 19153                          None                               False
# 19154                          None                               False
# 19157                          None                               False
# 19160                          None                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 469                                             rejected
# 473    https://data.globe.gov/system/photos/2018/08/1...
# 475    https://data.globe.gov/system/photos/2018/08/1...
# 476                                             rejected
# 481    https://data.globe.gov/system/photos/2018/08/1...
# ...                                                  ...
# 19152                                               None
# 19153                                               None
# 19154                                               None
# 19157                                               None
# 19160                                               None
#
#        mosquitohabitatmapperDataSource  \
# 469                 GLOBE Observer App
# 473                 GLOBE Observer App
# 475                 GLOBE Observer App
# 476                 GLOBE Observer App
# 481                 GLOBE Observer App
# ...                                ...
# 19152               GLOBE Observer App
# 19153               GLOBE Observer App
# 19154               GLOBE Observer App
# 19157               GLOBE Observer App
# 19160               GLOBE Observer App
#
#        mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 469                                           None
# 473                                           None
# 475                                           None
# 476                                           None
# 481                                           None
# ...                                            ...
# 19152                                         None
# 19153                                         None
# 19154                                         None
# 19157                                         None
# 19160                                         None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 469                                     8.6437
# 473                                     8.6436
# 475                                     8.6436
# 476                                     8.6436
# 481                                     8.6437
# ...                                        ...
# 19152                                  19.0461
# 19153                                  19.0461
# 19154                                  19.0461
# 19157                                  19.0461
# 19160                                  19.0461
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 469                                     None
# 473                                     None
# 475                                 identify
# 476                                     None
# 481                                     None
# ...                                      ...
# 19152                               identify
# 19153                               identify
# 19154                               identify
# 19157                               identify
# 19160                               identify
#
#       mosquitohabitatmapperWaterSourceType  \
# 469                 still: lake/pond/swamp
# 473                 still: lake/pond/swamp
# 475                 still: lake/pond/swamp
# 476                 still: lake/pond/swamp
# 481                 still: lake/pond/swamp
# ...                                    ...
# 19152                container: artificial
# 19153                container: artificial
# 19154                container: artificial
# 19157                container: artificial
# 19160                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 469                                           3856
# 473                                           3858
# 475                                           3877
# 476                                           3855
# 481                                           4044
# ...                                            ...
# 19152                                        22336
# 19153                                        22345
# 19154                                        22344
# 19157                                        22320
# 19160                                        22334
#
#        mosquitohabitatmapperMeasurementLongitude
# 469                                      99.8984
# 473                                      99.8985
# 475                                      99.8983
# 476                                      99.8985
# 481                                      99.8981
# ...                                          ...
# 19152                                    98.6550
# 19153                                    98.6550
# 19154                                    98.6550
# 19157                                    98.6549
# 19160                                    98.6549
#
# [2369 rows x 38 columns]

# %%
suspect_mask = df.isin(suspect_df)

clean_df = df[~suspect_mask].dropna(how = "all")

clean_df.to_csv("Clean CSV.csv")

# display's cleaned data
clean_df
# Out:
#                       protocol measuredDate           createDate  \
# 0      mosquito_habitat_mapper   2018-11-25  2020-01-25T18:09:52
# 1      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 2      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 3      mosquito_habitat_mapper   2019-05-29  2020-01-25T18:29:36
# 4      mosquito_habitat_mapper   2019-08-04  2020-01-25T18:45:20
# ...                        ...          ...                  ...
# 19277  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 19278  mosquito_habitat_mapper   2020-05-29  2020-06-03T07:30:03
# 19279  mosquito_habitat_mapper   2020-05-06  2020-07-14T08:40:05
# 19280  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
# 19281  mosquito_habitat_mapper   2020-01-29  2020-07-23T07:13:04
#
#                 updateDate          publishDate  organizationId  \
# 0      2020-01-25T18:09:52  2020-02-14T20:29:11      13063641.0
# 1      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 2      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 3      2020-01-25T18:29:36  2020-03-20T22:19:48      13063641.0
# 4      2020-01-25T18:45:20  2020-03-20T22:19:48      13063641.0
# ...                    ...                  ...             ...
# 19277  2020-05-30T19:30:02  2020-10-26T21:48:32      14054356.0
# 19278  2020-06-03T16:15:20  2020-10-26T21:48:32      19841715.0
# 19279  2020-07-14T13:40:07  2020-10-26T21:48:32      18306968.0
# 19280  2020-07-18T23:35:02  2020-10-26T21:48:32      14054356.0
# 19281  2020-07-23T07:13:04  2020-10-26T21:48:32        217639.0
#
#                          organizationName    siteId     siteName  \
# 0                   GPM Satellite Mission   35785.0  18SUJ105472
# 1                   GPM Satellite Mission   35785.0  18SUJ105472
# 2                   GPM Satellite Mission   35785.0  18SUJ105472
# 3                   GPM Satellite Mission   35785.0  18SUJ105472
# 4                   GPM Satellite Mission   35785.0  18SUJ105472
# ...                                   ...       ...          ...
# 19277                     lycee Thilmakha  200580.0  28PCB553673
# 19278          Madagascar Citizen Science  201123.0  38KQE645064
# 19279  Taiwan Partnership Citizen Science  208771.0  51RUH399684
# 19280                     lycee Thilmakha  209660.0  28PDB055429
# 19281  Suranaree University of Technology  210372.0  47PNK984553
#
#          countryName  ... mosquitohabitatmapperComments  \
# 0      United States  ...                          None
# 1      United States  ...                          None
# 2      United States  ...                          None
# 3      United States  ...                          None
# 4      United States  ...                          None
# ...              ...  ...                           ...
# 19277        Senegal  ...                          None
# 19278           None  ...                          None
# 19279           None  ...                          None
# 19280        Senegal  ...                          None
# 19281       Thailand  ...                          None
#
#        mosquitohabitatmapperMosquitoPupae  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 19277                                True
# 19278                               False
# 19279                                True
# 19280                                True
# 19281                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0      https://data.globe.gov/system/photos/2018/11/2...
# 1      https://data.globe.gov/system/photos/2019/04/0...
# 2      https://data.globe.gov/system/photos/2019/04/0...
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4      https://data.globe.gov/system/photos/2019/08/0...
# ...                                                  ...
# 19277  https://data.globe.gov/system/photos/2020/05/3...
# 19278  https://data.globe.gov/system/photos/2020/05/2...
# 19279                                               None
# 19280  https://data.globe.gov/system/photos/2020/05/3...
# 19281                                               None
#
#        mosquitohabitatmapperDataSource  \
# 0                   GLOBE Observer App
# 1                   GLOBE Observer App
# 2                   GLOBE Observer App
# 3                   GLOBE Observer App
# 4                   GLOBE Observer App
# ...                                ...
# 19277               GLOBE Observer App
# 19278               GLOBE Observer App
# 19279               GLOBE Observer App
# 19280               GLOBE Observer App
# 19281               GLOBE Observer App
#
#              mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4                                                   None
# ...                                                  ...
# 19277  https://data.globe.gov/system/photos/2020/05/3...
# 19278                                               None
# 19279  https://data.globe.gov/system/photos/2020/05/0...
# 19280                                               None
# 19281                                               None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                      39.2538
# 1                                      39.2535
# 2                                      39.2536
# 3                                      39.2542
# 4                                      39.2536
# ...                                        ...
# 19277                                  15.0777
# 19278                                 -18.9168
# 19279                                  25.0235
# 19280                                  14.8591
# 19281                                   8.6420
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 0                                       None
# 1                                   identify
# 2                                   identify
# 3                     identify-siphon-pecten
# 4                                   identify
# ...                                      ...
# 19277                 identify-siphon-pecten
# 19278                               identify
# 19279                    identify-basal-tuft
# 19280                    identify-aedes-tuft
# 19281                    identify-photo-prep
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                    container: artificial
# 1                    container: artificial
# 2                    container: artificial
# 3                    container: artificial
# 4                    container: artificial
# ...                                    ...
# 19277                container: artificial
# 19278                container: artificial
# 19279                container: artificial
# 19280                container: artificial
# 19281                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                           5188.0
# 1                                          10365.0
# 2                                          10360.0
# 3                                          12424.0
# 4                                          14822.0
# ...                                            ...
# 19277                                      22779.0
# 19278                                      22806.0
# 19279                                      24654.0
# 19280                                      24880.0
# 19281                                      25049.0
#
#        mosquitohabitatmapperMeasurementLongitude
# 0                                       -77.1959
# 1                                       -77.1960
# 2                                       -77.1956
# 3                                       -77.1962
# 4                                       -77.1957
# ...                                          ...
# 19277                                   -16.3463
# 19278                                    47.5121
# 19279                                   121.4134
# 19280                                   -15.8784
# 19281                                    99.8951
#
# [16913 rows x 38 columns]

# %% [markdown]
# # Anomaly Removal
#
# The following two cells are designed to remove anomalous (overreporting) mosquito larvae from the dataset (e.g., reporting 1,000 mosquito larvae), and resolve any sets of reported ranges (e.g., 1-25) by choosing the upper bound.
#
# ## Anomaly Threshold Variable
# This is the threshold for the number of reported mosquito larvae that marks an entry as an anomaly. It will remove any entries that have mosquito larvae count observed higher than this number.

# %%
anomaly_threshold = 1000

# %%
import re
def to_int(x):
    try:
        return int(x)
    except ValueError:
        try:
            return int(re.sub(r".*-", "", x))
        except ValueError:
            return 0

vectorized_int = np.vectorize(to_int)
clean_df["mosquitohabitatmapperLarvaeCount"] = vectorized_int(clean_df["mosquitohabitatmapperLarvaeCount"].fillna(0).values)
clean_df = clean_df[clean_df["mosquitohabitatmapperLarvaeCount"] < anomaly_threshold]
clean_df.to_csv("CleanDF Updated.csv")

clean_df
# Out:
#                       protocol measuredDate           createDate  \
# 0      mosquito_habitat_mapper   2018-11-25  2020-01-25T18:09:52
# 1      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 2      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 3      mosquito_habitat_mapper   2019-05-29  2020-01-25T18:29:36
# 4      mosquito_habitat_mapper   2019-08-04  2020-01-25T18:45:20
# ...                        ...          ...                  ...
# 19277  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 19278  mosquito_habitat_mapper   2020-05-29  2020-06-03T07:30:03
# 19279  mosquito_habitat_mapper   2020-05-06  2020-07-14T08:40:05
# 19280  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
# 19281  mosquito_habitat_mapper   2020-01-29  2020-07-23T07:13:04
#
#                 updateDate          publishDate  organizationId  \
# 0      2020-01-25T18:09:52  2020-02-14T20:29:11      13063641.0
# 1      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 2      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 3      2020-01-25T18:29:36  2020-03-20T22:19:48      13063641.0
# 4      2020-01-25T18:45:20  2020-03-20T22:19:48      13063641.0
# ...                    ...                  ...             ...
# 19277  2020-05-30T19:30:02  2020-10-26T21:48:32      14054356.0
# 19278  2020-06-03T16:15:20  2020-10-26T21:48:32      19841715.0
# 19279  2020-07-14T13:40:07  2020-10-26T21:48:32      18306968.0
# 19280  2020-07-18T23:35:02  2020-10-26T21:48:32      14054356.0
# 19281  2020-07-23T07:13:04  2020-10-26T21:48:32        217639.0
#
#                          organizationName    siteId     siteName  \
# 0                   GPM Satellite Mission   35785.0  18SUJ105472
# 1                   GPM Satellite Mission   35785.0  18SUJ105472
# 2                   GPM Satellite Mission   35785.0  18SUJ105472
# 3                   GPM Satellite Mission   35785.0  18SUJ105472
# 4                   GPM Satellite Mission   35785.0  18SUJ105472
# ...                                   ...       ...          ...
# 19277                     lycee Thilmakha  200580.0  28PCB553673
# 19278          Madagascar Citizen Science  201123.0  38KQE645064
# 19279  Taiwan Partnership Citizen Science  208771.0  51RUH399684
# 19280                     lycee Thilmakha  209660.0  28PDB055429
# 19281  Suranaree University of Technology  210372.0  47PNK984553
#
#          countryName  ... mosquitohabitatmapperComments  \
# 0      United States  ...                          None
# 1      United States  ...                          None
# 2      United States  ...                          None
# 3      United States  ...                          None
# 4      United States  ...                          None
# ...              ...  ...                           ...
# 19277        Senegal  ...                          None
# 19278           None  ...                          None
# 19279           None  ...                          None
# 19280        Senegal  ...                          None
# 19281       Thailand  ...                          None
#
#        mosquitohabitatmapperMosquitoPupae  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 19277                                True
# 19278                               False
# 19279                                True
# 19280                                True
# 19281                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0      https://data.globe.gov/system/photos/2018/11/2...
# 1      https://data.globe.gov/system/photos/2019/04/0...
# 2      https://data.globe.gov/system/photos/2019/04/0...
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4      https://data.globe.gov/system/photos/2019/08/0...
# ...                                                  ...
# 19277  https://data.globe.gov/system/photos/2020/05/3...
# 19278  https://data.globe.gov/system/photos/2020/05/2...
# 19279                                               None
# 19280  https://data.globe.gov/system/photos/2020/05/3...
# 19281                                               None
#
#        mosquitohabitatmapperDataSource  \
# 0                   GLOBE Observer App
# 1                   GLOBE Observer App
# 2                   GLOBE Observer App
# 3                   GLOBE Observer App
# 4                   GLOBE Observer App
# ...                                ...
# 19277               GLOBE Observer App
# 19278               GLOBE Observer App
# 19279               GLOBE Observer App
# 19280               GLOBE Observer App
# 19281               GLOBE Observer App
#
#              mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4                                                   None
# ...                                                  ...
# 19277  https://data.globe.gov/system/photos/2020/05/3...
# 19278                                               None
# 19279  https://data.globe.gov/system/photos/2020/05/0...
# 19280                                               None
# 19281                                               None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                      39.2538
# 1                                      39.2535
# 2                                      39.2536
# 3                                      39.2542
# 4                                      39.2536
# ...                                        ...
# 19277                                  15.0777
# 19278                                 -18.9168
# 19279                                  25.0235
# 19280                                  14.8591
# 19281                                   8.6420
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 0                                       None
# 1                                   identify
# 2                                   identify
# 3                     identify-siphon-pecten
# 4                                   identify
# ...                                      ...
# 19277                 identify-siphon-pecten
# 19278                               identify
# 19279                    identify-basal-tuft
# 19280                    identify-aedes-tuft
# 19281                    identify-photo-prep
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                    container: artificial
# 1                    container: artificial
# 2                    container: artificial
# 3                    container: artificial
# 4                    container: artificial
# ...                                    ...
# 19277                container: artificial
# 19278                container: artificial
# 19279                container: artificial
# 19280                container: artificial
# 19281                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                           5188.0
# 1                                          10365.0
# 2                                          10360.0
# 3                                          12424.0
# 4                                          14822.0
# ...                                            ...
# 19277                                      22779.0
# 19278                                      22806.0
# 19279                                      24654.0
# 19280                                      24880.0
# 19281                                      25049.0
#
#        mosquitohabitatmapperMeasurementLongitude
# 0                                       -77.1959
# 1                                       -77.1960
# 2                                       -77.1956
# 3                                       -77.1962
# 4                                       -77.1957
# ...                                          ...
# 19277                                   -16.3463
# 19278                                    47.5121
# 19279                                   121.4134
# 19280                                   -15.8784
# 19281                                    99.8951
#
# [16886 rows x 38 columns]

# %% [markdown]
# # Event Photo Downloading Script
#
# The following script downloads photos associated with possible mosquito mapper training events (identified in the previous script) in addition to other information to help a human identify later identify which groups were truly training events. This can also aid in future research exploring these training events.
#
# The procedure is as follows:
# - It gets the identified training events from the previous script
# - It generates a CSV of these events for future reference
# - For each group, it creates a subfolder and proceeds to do the following:
#     - Download all the photos collected in the suspected group
#     - Create a CSV containing all the photo file names, urls, and attributions
#     - Create a CSV containing all the entries for that group

# %%
# identify groups
suspect_groups = suspect_df.groupby(by = ['measuredDate','latitude','mosquitohabitatmapperWaterSource','siteName','longitude'])

# %%
# create a groups dataset
groups_list = []
groups_data = pd.DataFrame()
for group, df in suspect_groups:
    groups_list.append(str(group))
    new_df = df.copy(True)
    new_df["Group Name"] = str(group)
    groups_data = groups_data.append(new_df, ignore_index = True)
groups_df= pd.DataFrame(groups_list, columns=["Group"])
groups_data.to_csv("Group Data.csv")
groups_df
# Out:
#                                                  Group
# 0    ('2018-07-30', 7.812627, 'other', '47NPJ040637...
# 1    ('2018-08-07', 7.812627, 'other', '47NPJ040637...
# 2    ('2018-08-14', 7.812627, 'other', '47NPJ040637...
# 3    ('2018-08-17', 8.643, 'pond', '47PNK988555', 9...
# 4    ('2018-09-01', 0.304885, 'cement, metal or pla...
# ..                                                 ...
# 112  ('2020-01-27', 15.037919, 'cement, metal or pl...
# 113  ('2020-01-27', 18.01673, 'well or cistern', '4...
# 114  ('2020-02-20', 15.040585, 'cement, metal or pl...
# 115  ('2020-03-04', 8.643917, 'cement, metal or pla...
# 116  ('2020-05-30', 15.077131, 'cement, metal or pl...
#
# [117 rows x 1 columns]

# %%
import os
# makes a results directory if it doesn't already exist
if not os.path.isdir("Results"):
        os.mkdir("Results")
        
# write the groups data to a csv
groups_df.to_csv("Results/groups.csv")

# %%
import re
def download_picture(url, directory):
    def get_picture(file_name):
        downloaded_obj = requests.get(url, allow_redirects=True)
        parent_dir = os.path.join(directory, file_name)
        with open(parent_dir, "wb") as file:
            file.write(downloaded_obj.content)

    if "https://" in url:
        photo_id = re.search(r'(?<=\d\d\d\d\/\d\d\/\d\d\/).*(?=\/)', url).group(0)
        file_name = f"{photo_id}.jpg".replace(":","-")
        get_picture(file_name)
        temp_dict = {
                        "image_name" : [file_name],
                        "origin" : "GLOBE",
                        "link" : [url],
                        "attribution" : "GLOBE",
                        "license" : "Creative Commons - share adapt attribute"
                    }
        return pd.DataFrame.from_dict(temp_dict)

# %%
# photodownloading script for suspect groups
for data, group in suspect_groups:
    pics = pd.DataFrame()
    name = f"{data[0]}-{data[2]}-{data[3]}".replace("/", "-")
    dir_name = f"Results/{name}"
    if not os.path.isdir(dir_name):
        os.mkdir(dir_name)
    group_water_source = group["mosquitohabitatmapperWaterSourcePhotoUrls"].dropna().tolist()
    group_abdomen = group["mosquitohabitatmapperAbdomenCloseupPhotoUrls"].dropna().tolist()
    group_larvae = group["mosquitohabitatmapperLarvaFullBodyPhotoUrls"].dropna().tolist()
    group_urls = group_water_source + group_abdomen + group_larvae
    for urls in group_urls:
        if urls:
            urls = urls.split(";")
            for url in urls:
                pics = pics.append(download_picture(url, dir_name), ignore_index = True)
                
    pics.to_csv(f"{dir_name}/pictures.csv")
    group.to_csv(f"{dir_name}/data.csv")

# %%
if not os.path.isdir("Clean Data"):
    os.mkdir("Clean Data")
        
# photodownloading script for clean data download
pics = pd.DataFrame()
water_source = clean_df["mosquitohabitatmapperWaterSourcePhotoUrls"].dropna().tolist()
abdomen = clean_df["mosquitohabitatmapperAbdomenCloseupPhotoUrls"].dropna().tolist()
larvae = clean_df["mosquitohabitatmapperLarvaFullBodyPhotoUrls"].dropna().tolist()
url_list = water_source + abdomen + larvae
for urls in url_list:
    if urls:
        urls = urls.split(";")
        for url in urls:
            pics = pics.append(download_picture(url, "Clean Data"), ignore_index = True)
                
pics.to_csv(f"Clean Data/pictures.csv")
