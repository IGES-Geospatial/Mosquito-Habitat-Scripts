# %%
import pandas as pd
import requests
import numpy as np
import re
import os

# %% [markdown]
# # Step 1 -- Get Input Data
# > Option 1: API Data Downloading Procedure
# > Option 2: CSV Upload Procedure

# %% [markdown]
# ## Option 1: API Downloading Data Procedure
#
# Downloading data follows these steps:
# - Request the non GEOJSON data from the GLOBE API
# - Get the results from the JSON and pass it into a pandas dataframe
# - Unpacks the "data" entry
# - Merge the data onto the original dataframe
# - Remove the "data" entry from the original dataframe

# %%
start_date = "2017-05-29"
end_date = "2020-05-31"
url = f"https://api.globe.gov/search/v1/measurement/protocol/measureddate/?protocols=mosquito_habitat_mapper&startdate={start_date}&enddate={end_date}&geojson=FALSE&sample=FALSE"

# Downloads data from the GLOBE API and saves into a pandas df
response = requests.get(url)
results = response.json()["results"]

df = pd.DataFrame(results)

#Expand the 'data' column by listing the contents and passing as a new dataframe
df = pd.concat([df, pd.DataFrame(list(df['data']))], axis=1)

#Drop the previously nested data column
df = df.drop('data', 1)

# Displays the dataframe
df
# Out:
#                       protocol measuredDate           createDate  \
# 0      mosquito_habitat_mapper   2018-11-25  2020-01-25T18:09:52
# 1      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 2      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 3      mosquito_habitat_mapper   2019-05-29  2020-01-25T18:29:36
# 4      mosquito_habitat_mapper   2019-08-04  2020-01-25T18:45:20
# ...                        ...          ...                  ...
# 22452  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 22453  mosquito_habitat_mapper   2020-05-29  2020-06-03T07:30:03
# 22454  mosquito_habitat_mapper   2020-05-06  2020-07-14T08:40:05
# 22455  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
# 22456  mosquito_habitat_mapper   2020-01-29  2020-07-23T07:13:04
#
#                 updateDate          publishDate  organizationId  \
# 0      2020-01-25T18:09:52  2020-02-14T20:29:11      13063641.0
# 1      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 2      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 3      2020-01-25T18:29:36  2020-03-20T22:19:48      13063641.0
# 4      2020-01-25T18:45:20  2020-03-20T22:19:48      13063641.0
# ...                    ...                  ...             ...
# 22452  2020-05-30T19:30:02  2020-11-23T21:32:54      14054356.0
# 22453  2020-06-03T16:15:20  2020-11-23T21:32:54      19841715.0
# 22454  2020-07-14T13:40:07  2020-11-23T21:32:54      18306968.0
# 22455  2020-07-18T23:35:02  2020-11-23T21:32:54      14054356.0
# 22456  2020-07-23T07:13:04  2020-11-23T21:32:54        217639.0
#
#                          organizationName  siteId     siteName    countryName  \
# 0                   GPM Satellite Mission   35785  18SUJ105472  United States
# 1                   GPM Satellite Mission   35785  18SUJ105472  United States
# 2                   GPM Satellite Mission   35785  18SUJ105472  United States
# 3                   GPM Satellite Mission   35785  18SUJ105472  United States
# 4                   GPM Satellite Mission   35785  18SUJ105472  United States
# ...                                   ...     ...          ...            ...
# 22452                     lycee Thilmakha  200580  28PCB553673        Senegal
# 22453          Madagascar Citizen Science  201123  38KQE645064           None
# 22454  Taiwan Partnership Citizen Science  208771  51RUH399684           None
# 22455                     lycee Thilmakha  209660  28PDB055429        Senegal
# 22456  Suranaree University of Technology  210372  47PNK984553       Thailand
#
#        ... mosquitohabitatmapperComments  mosquitohabitatmapperMosquitoPupae  \
# 0      ...                          None                               False
# 1      ...                          None                               False
# 2      ...                          None                               False
# 3      ...                          None                               False
# 4      ...                          None                               False
# ...    ...                           ...                                 ...
# 22452  ...                          None                                True
# 22453  ...                          None                               False
# 22454  ...                          None                                True
# 22455  ...                          None                                True
# 22456  ...                          None                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0      https://data.globe.gov/system/photos/2018/11/2...
# 1      https://data.globe.gov/system/photos/2019/04/0...
# 2      https://data.globe.gov/system/photos/2019/04/0...
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4      https://data.globe.gov/system/photos/2019/08/0...
# ...                                                  ...
# 22452  https://data.globe.gov/system/photos/2020/05/3...
# 22453  https://data.globe.gov/system/photos/2020/05/2...
# 22454                                               None
# 22455  https://data.globe.gov/system/photos/2020/05/3...
# 22456                                               None
#
#        mosquitohabitatmapperDataSource  \
# 0                   GLOBE Observer App
# 1                   GLOBE Observer App
# 2                   GLOBE Observer App
# 3                   GLOBE Observer App
# 4                   GLOBE Observer App
# ...                                ...
# 22452               GLOBE Observer App
# 22453               GLOBE Observer App
# 22454               GLOBE Observer App
# 22455               GLOBE Observer App
# 22456               GLOBE Observer App
#
#              mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4                                                   None
# ...                                                  ...
# 22452  https://data.globe.gov/system/photos/2020/05/3...
# 22453                                               None
# 22454  https://data.globe.gov/system/photos/2020/05/0...
# 22455                                               None
# 22456                                               None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                      39.2538
# 1                                      39.2535
# 2                                      39.2536
# 3                                      39.2542
# 4                                      39.2536
# ...                                        ...
# 22452                                  15.0778
# 22453                                 -18.9168
# 22454                                  25.0235
# 22455                                  14.8591
# 22456                                   8.6420
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 0                                       None
# 1                                   identify
# 2                                   identify
# 3                     identify-siphon-pecten
# 4                                   identify
# ...                                      ...
# 22452                  identify-siphon-shape
# 22453                               identify
# 22454                    identify-basal-tuft
# 22455                    identify-aedes-tuft
# 22456                    identify-photo-prep
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                    container: artificial
# 1                    container: artificial
# 2                    container: artificial
# 3                    container: artificial
# 4                    container: artificial
# ...                                    ...
# 22452                container: artificial
# 22453                container: artificial
# 22454                container: artificial
# 22455                container: artificial
# 22456                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                             5188
# 1                                            10365
# 2                                            10360
# 3                                            12424
# 4                                            14822
# ...                                            ...
# 22452                                        22772
# 22453                                        22806
# 22454                                        24654
# 22455                                        24880
# 22456                                        25049
#
#        mosquitohabitatmapperMeasurementLongitude
# 0                                       -77.1959
# 1                                       -77.1960
# 2                                       -77.1956
# 3                                       -77.1962
# 4                                       -77.1957
# ...                                          ...
# 22452                                   -16.3463
# 22453                                    47.5121
# 22454                                   121.4134
# 22455                                   -15.8784
# 22456                                    99.8951
#
# [22457 rows x 38 columns]

# %% [markdown]
# ## Option 2: CSV Downloading
#
# This cell allows for the option of using mosquito mapper data from CSV Files.
#
# This enables an analysis of different subsets of the total mosquito mapper data (this will overwrite data downloaded from the API).

# %%
filename = "Africa.csv"
df = pd.read_csv(filename)
df
# Out:
#       Unnamed: 0                 protocol measuredDate           createDate  \
# 0            594  mosquito_habitat_mapper   2017-07-05  2020-01-25T17:36:06
# 1            635  mosquito_habitat_mapper   2017-07-06  2020-01-25T17:36:06
# 2            640  mosquito_habitat_mapper   2017-07-07  2020-01-25T17:36:06
# 3           2618  mosquito_habitat_mapper   2017-08-01  2020-01-25T17:36:55
# 4           3410  mosquito_habitat_mapper   2018-09-08  2020-01-25T18:05:43
# ...          ...                      ...          ...                  ...
# 4537       22449  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 4538       22450  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 4539       22451  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 4540       22452  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 4541       22455  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
#
#                updateDate          publishDate  organizationId  \
# 0     2020-01-25T17:36:06  2020-02-14T20:29:11      23351884.0
# 1     2020-01-25T17:36:06  2020-02-14T20:29:11      24610401.0
# 2     2020-01-25T17:36:06  2020-02-14T20:29:11      24610401.0
# 3     2020-01-25T17:36:55  2020-02-14T20:29:11        236305.0
# 4     2020-01-25T18:05:43  2020-02-14T20:29:11        127300.0
# ...                   ...                  ...             ...
# 4537  2020-05-30T19:30:02  2020-11-23T21:32:54      14054356.0
# 4538  2020-05-30T19:30:02  2020-11-23T21:32:54      14054356.0
# 4539  2020-05-30T19:30:02  2020-11-23T21:32:54      14054356.0
# 4540  2020-05-30T19:30:02  2020-11-23T21:32:54      14054356.0
# 4541  2020-07-18T23:35:02  2020-11-23T21:32:54      14054356.0
#
#                                organizationName  siteId     siteName  ...  \
# 0     Twene Amanfo Senior High/Technical School   53048  30NWP747107  ...
# 1                               Terre Rouge SSS   53208  40KEC556754  ...
# 2                               Terre Rouge SSS   53238  40KEC557756  ...
# 3                      Kabojja Secondary School   99016  18TXL725776  ...
# 4                        Indwe Secondary School  106855  34HFH012220  ...
# ...                                         ...     ...          ...  ...
# 4537                            lycee Thilmakha  200580  28PCB553673  ...
# 4538                            lycee Thilmakha  200580  28PCB553673  ...
# 4539                            lycee Thilmakha  200580  28PCB553673  ...
# 4540                            lycee Thilmakha  200580  28PCB553673  ...
# 4541                            lycee Thilmakha  209660  28PDB055429  ...
#
#      mosquitohabitatmapperComments mosquitohabitatmapperMosquitoPupae  \
# 0                              NaN                                NaN
# 1                              NaN                               True
# 2                              NaN                               True
# 3                              NaN                               True
# 4                              NaN                                NaN
# ...                            ...                                ...
# 4537                           NaN                               True
# 4538                           NaN                               True
# 4539                           NaN                               True
# 4540                           NaN                               True
# 4541                           NaN                               True
#
#               mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0     https://data.globe.gov/system/photos/2017/07/0...
# 1                                                   NaN
# 2                                                   NaN
# 3     https://data.globe.gov/system/photos/2017/08/0...
# 4     https://data.globe.gov/system/photos/2018/09/0...
# ...                                                 ...
# 4537  https://data.globe.gov/system/photos/2020/05/3...
# 4538  https://data.globe.gov/system/photos/2020/05/3...
# 4539  https://data.globe.gov/system/photos/2020/05/3...
# 4540  https://data.globe.gov/system/photos/2020/05/3...
# 4541  https://data.globe.gov/system/photos/2020/05/3...
#
#       mosquitohabitatmapperDataSource  \
# 0                  GLOBE Observer App
# 1                  GLOBE Observer App
# 2                  GLOBE Observer App
# 3                  GLOBE Observer App
# 4                  GLOBE Observer App
# ...                               ...
# 4537               GLOBE Observer App
# 4538               GLOBE Observer App
# 4539               GLOBE Observer App
# 4540               GLOBE Observer App
# 4541               GLOBE Observer App
#
#             mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   NaN
# 1     https://data.globe.gov/system/photos/2017/07/0...
# 2     https://data.globe.gov/system/photos/2017/07/0...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4537  https://data.globe.gov/system/photos/2020/05/3...
# 4538  https://data.globe.gov/system/photos/2020/05/3...
# 4539  https://data.globe.gov/system/photos/2020/05/3...
# 4540  https://data.globe.gov/system/photos/2020/05/3...
# 4541                                                NaN
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                     7.333747
# 1                                   -20.117747
# 2                                   -20.115937
# 3                                    41.331432
# 4                                   -34.137100
# ...                                        ...
# 4537                                 15.077700
# 4538                                 15.077700
# 4539                                 15.077800
# 4540                                 15.077800
# 4541                                 14.859100
#
#      mosquitohabitatmapperLastIdentifyStage  \
# 0                                       NaN
# 1                     identify-siphon-shape
# 2                        identify-no-siphon
# 3                                  identify
# 4                                       NaN
# ...                                     ...
# 4537                  identify-siphon-shape
# 4538                 identify-siphon-pecten
# 4539                  identify-siphon-shape
# 4540                  identify-siphon-shape
# 4541                    identify-aedes-tuft
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                   still: lake/pond/swamp
# 1                   still: lake/pond/swamp
# 2                    container: artificial
# 3                   still: lake/pond/swamp
# 4                    container: artificial
# ...                                    ...
# 4537                 container: artificial
# 4538                 container: artificial
# 4539                 container: artificial
# 4540                 container: artificial
# 4541                 container: artificial
#
#      mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                             137
# 1                                             100
# 2                                             104
# 3                                             935
# 4                                            4401
# ...                                           ...
# 4537                                        22776
# 4538                                        22779
# 4539                                        22768
# 4540                                        22772
# 4541                                        24880
#
#      mosquitohabitatmapperMeasurementLongitude
# 0                                    -2.323205
# 1                                    57.531913
# 2                                    57.532863
# 3                                   -72.938605
# 4                                    22.098000
# ...                                        ...
# 4537                                -16.346300
# 4538                                -16.346300
# 4539                                -16.346300
# 4540                                -16.346300
# 4541                                -15.878400
#
# [4542 rows x 39 columns]

# %% [markdown]
# # Step 2 -- GeoLocational Data Cleaning Procedure:
# > Removes bad geo-locational data. Examples of bad location data include:
#  * Site Latitude and Longitude match GPS Latitude and Longitude (These values should differ)
#  * Integer GPS Measurements (GPS Measurements should be very precise decimals)

# %%
# Finds all bad locational data
def geolocational_filter(gps_lat, gps_lon, recorded_lat, recorded_lon):
    return ((recorded_lat == gps_lat and 
        recorded_lon == gps_lon) or
         gps_lat == int(gps_lat) or
         gps_lon == int(gps_lon)
        )

vectorized_filter = np.vectorize(geolocational_filter)
bad_data = vectorized_filter(df["mosquitohabitatmapperMeasurementLatitude"].to_numpy(),
                             df["mosquitohabitatmapperMeasurementLongitude"].to_numpy(),
                             df["latitude"].to_numpy(),
                             df["longitude"].to_numpy()
                            )

# Removes all bad locational data from the working dataframe
df = df[~bad_data]
df = df.reset_index().drop(["index"], axis = 1)

# Writes filtered data to a csv
df.to_csv("Geolocation.csv")

df
# Out:
#       Unnamed: 0                 protocol measuredDate           createDate  \
# 0           3410  mosquito_habitat_mapper   2018-09-08  2020-01-25T18:05:43
# 1           4927  mosquito_habitat_mapper   2018-06-30  2020-01-25T17:58:58
# 2           4928  mosquito_habitat_mapper   2018-06-30  2020-01-25T17:58:58
# 3           5058  mosquito_habitat_mapper   2018-07-03  2020-01-25T18:00:55
# 4           5063  mosquito_habitat_mapper   2018-07-03  2020-01-25T18:00:55
# ...          ...                      ...          ...                  ...
# 4481       22449  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 4482       22450  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 4483       22451  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 4484       22452  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 4485       22455  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
#
#                updateDate          publishDate  organizationId  \
# 0     2020-01-25T18:05:43  2020-02-14T20:29:11        127300.0
# 1     2020-01-25T17:58:58  2020-02-14T20:29:11      10532743.0
# 2     2020-01-25T17:58:58  2020-02-14T20:29:11      10532743.0
# 3     2020-01-25T18:00:55  2020-02-14T20:29:11      10532743.0
# 4     2020-01-25T18:00:55  2020-02-14T20:29:11      10532743.0
# ...                   ...                  ...             ...
# 4481  2020-05-30T19:30:02  2020-11-23T21:32:54      14054356.0
# 4482  2020-05-30T19:30:02  2020-11-23T21:32:54      14054356.0
# 4483  2020-05-30T19:30:02  2020-11-23T21:32:54      14054356.0
# 4484  2020-05-30T19:30:02  2020-11-23T21:32:54      14054356.0
# 4485  2020-07-18T23:35:02  2020-11-23T21:32:54      14054356.0
#
#             organizationName  siteId     siteName  ...  \
# 0     Indwe Secondary School  106855  34HFH012220  ...
# 1      Africa GLOBE v-School  132251  36NVF470218  ...
# 2      Africa GLOBE v-School  132256  36NVF477242  ...
# 3      Africa GLOBE v-School  132455  36NVF504347  ...
# 4      Africa GLOBE v-School  132496  36NVF511349  ...
# ...                      ...     ...          ...  ...
# 4481         lycee Thilmakha  200580  28PCB553673  ...
# 4482         lycee Thilmakha  200580  28PCB553673  ...
# 4483         lycee Thilmakha  200580  28PCB553673  ...
# 4484         lycee Thilmakha  200580  28PCB553673  ...
# 4485         lycee Thilmakha  209660  28PDB055429  ...
#
#                           mosquitohabitatmapperComments  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     we are going to destroy the habitat by using t...
# 4                                                   NaN
# ...                                                 ...
# 4481                                                NaN
# 4482                                                NaN
# 4483                                                NaN
# 4484                                                NaN
# 4485                                                NaN
#
#      mosquitohabitatmapperMosquitoPupae  \
# 0                                   NaN
# 1                                  True
# 2                                  True
# 3                                 False
# 4                                 False
# ...                                 ...
# 4481                               True
# 4482                               True
# 4483                               True
# 4484                               True
# 4485                               True
#
#               mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0     https://data.globe.gov/system/photos/2018/09/0...
# 1     https://data.globe.gov/system/photos/2018/06/3...
# 2     https://data.globe.gov/system/photos/2018/06/3...
# 3     https://data.globe.gov/system/photos/2018/07/0...
# 4     https://data.globe.gov/system/photos/2018/07/0...
# ...                                                 ...
# 4481  https://data.globe.gov/system/photos/2020/05/3...
# 4482  https://data.globe.gov/system/photos/2020/05/3...
# 4483  https://data.globe.gov/system/photos/2020/05/3...
# 4484  https://data.globe.gov/system/photos/2020/05/3...
# 4485  https://data.globe.gov/system/photos/2020/05/3...
#
#       mosquitohabitatmapperDataSource  \
# 0                  GLOBE Observer App
# 1                  GLOBE Observer App
# 2                  GLOBE Observer App
# 3                  GLOBE Observer App
# 4                  GLOBE Observer App
# ...                               ...
# 4481               GLOBE Observer App
# 4482               GLOBE Observer App
# 4483               GLOBE Observer App
# 4484               GLOBE Observer App
# 4485               GLOBE Observer App
#
#             mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   NaN
# 1     https://data.globe.gov/system/photos/2018/06/3...
# 2     https://data.globe.gov/system/photos/2018/06/3...
# 3     https://data.globe.gov/system/photos/2018/07/0...
# 4     https://data.globe.gov/system/photos/2018/07/0...
# ...                                                 ...
# 4481  https://data.globe.gov/system/photos/2020/05/3...
# 4482  https://data.globe.gov/system/photos/2020/05/3...
# 4483  https://data.globe.gov/system/photos/2020/05/3...
# 4484  https://data.globe.gov/system/photos/2020/05/3...
# 4485                                                NaN
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                   -34.137100
# 1                                     0.197667
# 2                                     0.219000
# 3                                     0.314200
# 4                                     0.316600
# ...                                        ...
# 4481                                 15.077700
# 4482                                 15.077700
# 4483                                 15.077800
# 4484                                 15.077800
# 4485                                 14.859100
#
#      mosquitohabitatmapperLastIdentifyStage  \
# 0                                       NaN
# 1                        identify-no-siphon
# 2                      identify-saddle-comb
# 3                    identify-no-basal-tuft
# 4                  identify-saddle-complete
# ...                                     ...
# 4481                  identify-siphon-shape
# 4482                 identify-siphon-pecten
# 4483                  identify-siphon-shape
# 4484                  identify-siphon-shape
# 4485                    identify-aedes-tuft
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                    container: artificial
# 1                    container: artificial
# 2                    container: artificial
# 3                    container: artificial
# 4                    container: artificial
# ...                                    ...
# 4481                 container: artificial
# 4482                 container: artificial
# 4483                 container: artificial
# 4484                 container: artificial
# 4485                 container: artificial
#
#      mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                            4401
# 1                                            3096
# 2                                            3097
# 3                                            3186
# 4                                            3191
# ...                                           ...
# 4481                                        22776
# 4482                                        22779
# 4483                                        22768
# 4484                                        22772
# 4485                                        24880
#
#      mosquitohabitatmapperMeasurementLongitude
# 0                                    22.098000
# 1                                    32.523838
# 2                                    32.530600
# 3                                    32.555000
# 4                                    32.561000
# ...                                        ...
# 4481                                -16.346300
# 4482                                -16.346300
# 4483                                -16.346300
# 4484                                -16.346300
# 4485                                -15.878400
#
# [4486 rows x 39 columns]

# %% [markdown]
# # Step 3 -- Suspected Training Event Removal
#
# We identify training groups (with similar observational data) and remove this training group data from the working dataframe.
#
# * We group entries with the same measured date, site latitude, site longitude, siteName, and water source.
# * We isolate groups with a size greater than our threshold (10 members/similar entries). We remove these groups and write their data into a separate CSV.

# %% [markdown]
# ## Threshold Variable
#
# The threshold variable is the minimum number of duplicate entries (exclusive) that are needed for the the group of entries to be classified as an event.
#
# Set the threshold value and then run the following cells

# %%
threshold = 10

# %%
# Groups / filters suspected events
suspect_df = df.groupby(by=['measuredDate','latitude','mosquitohabitatmapperWaterSource','siteName','longitude']).filter(lambda x: len(x) > threshold)

# Writes the entries to a CSV
suspect_df.to_csv("Possible Events.csv")       

# Displays the suspected entries
suspect_df
# Out:
#                       protocol measuredDate           createDate  \
# 229    mosquito_habitat_mapper   2017-08-30  2020-01-25T17:36:55
# 1355   mosquito_habitat_mapper   2017-08-30  2020-01-25T17:36:55
# 1356   mosquito_habitat_mapper   2017-08-30  2020-01-25T17:36:55
# 1357   mosquito_habitat_mapper   2017-08-30  2020-01-25T17:36:55
# 1359   mosquito_habitat_mapper   2017-08-30  2020-01-25T17:36:55
# ...                        ...          ...                  ...
# 22329  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
# 22330  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
# 22331  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
# 22334  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
# 22335  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
#
#                 updateDate          publishDate  organizationId  \
# 229    2020-01-25T17:36:55  2020-02-14T20:29:11        191867.0
# 1355   2020-01-25T17:36:55  2020-02-14T20:29:11      17615655.0
# 1356   2020-01-25T17:36:55  2020-02-14T20:29:11      17615655.0
# 1357   2020-01-25T17:36:55  2020-02-14T20:29:11      17615655.0
# 1359   2020-01-25T17:36:55  2020-02-14T20:29:11      17615655.0
# ...                    ...                  ...             ...
# 22329  2020-04-20T07:31:25  2020-11-23T21:32:54      17615655.0
# 22330  2020-04-20T07:31:25  2020-11-23T21:32:54      17615655.0
# 22331  2020-04-20T07:31:25  2020-11-23T21:32:54      17615655.0
# 22334  2020-04-20T07:31:25  2020-11-23T21:32:54      17615655.0
# 22335  2020-04-20T07:31:25  2020-11-23T21:32:54      17615655.0
#
#                organizationName  siteId     siteName countryName  ...  \
# 229         Walailak University   49206  47PNK987556    Thailand  ...
# 1355   Thailand Citizen Science   97675  47PNK987556        None  ...
# 1356   Thailand Citizen Science   97675  47PNK987556        None  ...
# 1357   Thailand Citizen Science   97675  47PNK987556        None  ...
# 1359   Thailand Citizen Science   97675  47PNK987556        None  ...
# ...                         ...     ...          ...         ...  ...
# 22329  Thailand Citizen Science  196380  47QMB636059        None  ...
# 22330  Thailand Citizen Science  196380  47QMB636059        None  ...
# 22331  Thailand Citizen Science  196380  47QMB636059        None  ...
# 22334  Thailand Citizen Science  196380  47QMB636059        None  ...
# 22335  Thailand Citizen Science  196380  47QMB636059        None  ...
#
#       mosquitohabitatmapperComments  mosquitohabitatmapperMosquitoPupae  \
# 229                            None                                None
# 1355                           None                                None
# 1356                           None                                None
# 1357                           None                                None
# 1359                           None                                None
# ...                             ...                                 ...
# 22329                          None                               False
# 22330                          None                               False
# 22331                          None                               False
# 22334                          None                               False
# 22335                          None                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 229    https://data.globe.gov/system/photos/2017/08/3...
# 1355   https://data.globe.gov/system/photos/2017/08/3...
# 1356   https://data.globe.gov/system/photos/2017/08/3...
# 1357   https://data.globe.gov/system/photos/2017/08/3...
# 1359   https://data.globe.gov/system/photos/2017/08/3...
# ...                                                  ...
# 22329                                               None
# 22330                                               None
# 22331                                               None
# 22334                                               None
# 22335                                               None
#
#        mosquitohabitatmapperDataSource  \
# 229                 GLOBE Observer App
# 1355                GLOBE Observer App
# 1356                GLOBE Observer App
# 1357                GLOBE Observer App
# 1359                GLOBE Observer App
# ...                                ...
# 22329               GLOBE Observer App
# 22330               GLOBE Observer App
# 22331               GLOBE Observer App
# 22334               GLOBE Observer App
# 22335               GLOBE Observer App
#
#        mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 229                                           None
# 1355                                          None
# 1356                                          None
# 1357                                          None
# 1359                                          None
# ...                                            ...
# 22329                                         None
# 22330                                         None
# 22331                                         None
# 22334                                         None
# 22335                                         None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 229                                   8.643907
# 1355                                  8.643907
# 1356                                  8.643907
# 1357                                  8.643907
# 1359                                  8.643907
# ...                                        ...
# 22329                                19.046100
# 22330                                19.046100
# 22331                                19.046100
# 22334                                19.046100
# 22335                                19.046100
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 229                                     None
# 1355                                    None
# 1356                                    None
# 1357                                    None
# 1359                                    None
# ...                                      ...
# 22329                               identify
# 22330                               identify
# 22331                               identify
# 22334                               identify
# 22335                               identify
#
#       mosquitohabitatmapperWaterSourceType  \
# 229                 still: lake/pond/swamp
# 1355                still: lake/pond/swamp
# 1356                still: lake/pond/swamp
# 1357                still: lake/pond/swamp
# 1359                still: lake/pond/swamp
# ...                                    ...
# 22329                container: artificial
# 22330                container: artificial
# 22331                container: artificial
# 22334                container: artificial
# 22335                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 229                                            485
# 1355                                           463
# 1356                                           505
# 1357                                           508
# 1359                                           451
# ...                                            ...
# 22329                                        22344
# 22330                                        22356
# 22331                                        22321
# 22334                                        22335
# 22335                                        22340
#
#        mosquitohabitatmapperMeasurementLongitude
# 229                                     99.89708
# 1355                                    99.89708
# 1356                                    99.89708
# 1357                                    99.89708
# 1359                                    99.89708
# ...                                          ...
# 22329                                   98.65500
# 22330                                   98.65490
# 22331                                   98.65490
# 22334                                   98.65490
# 22335                                   98.65500
#
# [2447 rows x 38 columns]

# %%
# Removes suspected group data from the working dataframe
suspect_mask = df.isin(suspect_df)

df = df[~suspect_mask].dropna(how = "all")

# Saves new cleaned data to a separate CSV
df.to_csv("Removed_Groups.csv")
df
# Out:
#                       protocol measuredDate           createDate  \
# 0      mosquito_habitat_mapper   2018-11-25  2020-01-25T18:09:52
# 1      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 2      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 3      mosquito_habitat_mapper   2019-05-29  2020-01-25T18:29:36
# 4      mosquito_habitat_mapper   2019-08-04  2020-01-25T18:45:20
# ...                        ...          ...                  ...
# 22452  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 22453  mosquito_habitat_mapper   2020-05-29  2020-06-03T07:30:03
# 22454  mosquito_habitat_mapper   2020-05-06  2020-07-14T08:40:05
# 22455  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
# 22456  mosquito_habitat_mapper   2020-01-29  2020-07-23T07:13:04
#
#                 updateDate          publishDate  organizationId  \
# 0      2020-01-25T18:09:52  2020-02-14T20:29:11      13063641.0
# 1      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 2      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 3      2020-01-25T18:29:36  2020-03-20T22:19:48      13063641.0
# 4      2020-01-25T18:45:20  2020-03-20T22:19:48      13063641.0
# ...                    ...                  ...             ...
# 22452  2020-05-30T19:30:02  2020-11-23T21:32:54      14054356.0
# 22453  2020-06-03T16:15:20  2020-11-23T21:32:54      19841715.0
# 22454  2020-07-14T13:40:07  2020-11-23T21:32:54      18306968.0
# 22455  2020-07-18T23:35:02  2020-11-23T21:32:54      14054356.0
# 22456  2020-07-23T07:13:04  2020-11-23T21:32:54        217639.0
#
#                          organizationName    siteId     siteName  \
# 0                   GPM Satellite Mission   35785.0  18SUJ105472
# 1                   GPM Satellite Mission   35785.0  18SUJ105472
# 2                   GPM Satellite Mission   35785.0  18SUJ105472
# 3                   GPM Satellite Mission   35785.0  18SUJ105472
# 4                   GPM Satellite Mission   35785.0  18SUJ105472
# ...                                   ...       ...          ...
# 22452                     lycee Thilmakha  200580.0  28PCB553673
# 22453          Madagascar Citizen Science  201123.0  38KQE645064
# 22454  Taiwan Partnership Citizen Science  208771.0  51RUH399684
# 22455                     lycee Thilmakha  209660.0  28PDB055429
# 22456  Suranaree University of Technology  210372.0  47PNK984553
#
#          countryName  ... mosquitohabitatmapperComments  \
# 0      United States  ...                          None
# 1      United States  ...                          None
# 2      United States  ...                          None
# 3      United States  ...                          None
# 4      United States  ...                          None
# ...              ...  ...                           ...
# 22452        Senegal  ...                          None
# 22453           None  ...                          None
# 22454           None  ...                          None
# 22455        Senegal  ...                          None
# 22456       Thailand  ...                          None
#
#        mosquitohabitatmapperMosquitoPupae  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 22452                                True
# 22453                               False
# 22454                                True
# 22455                                True
# 22456                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0      https://data.globe.gov/system/photos/2018/11/2...
# 1      https://data.globe.gov/system/photos/2019/04/0...
# 2      https://data.globe.gov/system/photos/2019/04/0...
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4      https://data.globe.gov/system/photos/2019/08/0...
# ...                                                  ...
# 22452  https://data.globe.gov/system/photos/2020/05/3...
# 22453  https://data.globe.gov/system/photos/2020/05/2...
# 22454                                               None
# 22455  https://data.globe.gov/system/photos/2020/05/3...
# 22456                                               None
#
#        mosquitohabitatmapperDataSource  \
# 0                   GLOBE Observer App
# 1                   GLOBE Observer App
# 2                   GLOBE Observer App
# 3                   GLOBE Observer App
# 4                   GLOBE Observer App
# ...                                ...
# 22452               GLOBE Observer App
# 22453               GLOBE Observer App
# 22454               GLOBE Observer App
# 22455               GLOBE Observer App
# 22456               GLOBE Observer App
#
#              mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4                                                   None
# ...                                                  ...
# 22452  https://data.globe.gov/system/photos/2020/05/3...
# 22453                                               None
# 22454  https://data.globe.gov/system/photos/2020/05/0...
# 22455                                               None
# 22456                                               None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                      39.2538
# 1                                      39.2535
# 2                                      39.2536
# 3                                      39.2542
# 4                                      39.2536
# ...                                        ...
# 22452                                  15.0778
# 22453                                 -18.9168
# 22454                                  25.0235
# 22455                                  14.8591
# 22456                                   8.6420
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 0                                       None
# 1                                   identify
# 2                                   identify
# 3                     identify-siphon-pecten
# 4                                   identify
# ...                                      ...
# 22452                  identify-siphon-shape
# 22453                               identify
# 22454                    identify-basal-tuft
# 22455                    identify-aedes-tuft
# 22456                    identify-photo-prep
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                    container: artificial
# 1                    container: artificial
# 2                    container: artificial
# 3                    container: artificial
# 4                    container: artificial
# ...                                    ...
# 22452                container: artificial
# 22453                container: artificial
# 22454                container: artificial
# 22455                container: artificial
# 22456                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                           5188.0
# 1                                          10365.0
# 2                                          10360.0
# 3                                          12424.0
# 4                                          14822.0
# ...                                            ...
# 22452                                      22772.0
# 22453                                      22806.0
# 22454                                      24654.0
# 22455                                      24880.0
# 22456                                      25049.0
#
#        mosquitohabitatmapperMeasurementLongitude
# 0                                       -77.1959
# 1                                       -77.1960
# 2                                       -77.1956
# 3                                       -77.1962
# 4                                       -77.1957
# ...                                          ...
# 22452                                   -16.3463
# 22453                                    47.5121
# 22454                                   121.4134
# 22455                                   -15.8784
# 22456                                    99.8951
#
# [20010 rows x 38 columns]

# %% [markdown]
# # Step 4 -- Anomaly Removal
#
# The following two cells are designed to remove anomalous (overreporting) mosquito larvae from the dataset (e.g., reporting 1,000 mosquito larvae), and resolve any sets of reported ranges (e.g., 1-25) by choosing the upper bound.
#
# ## Anomaly Threshold Variable
# This is the threshold for the number of reported mosquito larvae that marks an entry as an anomaly. It will remove any entries that have mosquito larvae count observed higher than this number.

# %%
anomaly_threshold = 1000

# %%
def to_int(x):
    try:
        return int(x)
    except ValueError:
        try:
            return int(re.sub(r".*-", "", x))
        except ValueError:
            return 0

vectorized_int = np.vectorize(to_int)
df["mosquitohabitatmapperLarvaeCount"] = vectorized_int(df["mosquitohabitatmapperLarvaeCount"].fillna(0).values)
df = df[df["mosquitohabitatmapperLarvaeCount"] < anomaly_threshold]
df.to_csv("Fixed_Larvae_Count.csv")
# Out:
#                       protocol measuredDate           createDate  \
# 0      mosquito_habitat_mapper   2018-11-25  2020-01-25T18:09:52
# 1      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 2      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 3      mosquito_habitat_mapper   2019-05-29  2020-01-25T18:29:36
# 4      mosquito_habitat_mapper   2019-08-04  2020-01-25T18:45:20
# ...                        ...          ...                  ...
# 22452  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 22453  mosquito_habitat_mapper   2020-05-29  2020-06-03T07:30:03
# 22454  mosquito_habitat_mapper   2020-05-06  2020-07-14T08:40:05
# 22455  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
# 22456  mosquito_habitat_mapper   2020-01-29  2020-07-23T07:13:04
#
#                 updateDate          publishDate  organizationId  \
# 0      2020-01-25T18:09:52  2020-02-14T20:29:11      13063641.0
# 1      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 2      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 3      2020-01-25T18:29:36  2020-03-20T22:19:48      13063641.0
# 4      2020-01-25T18:45:20  2020-03-20T22:19:48      13063641.0
# ...                    ...                  ...             ...
# 22452  2020-05-30T19:30:02  2020-11-23T21:32:54      14054356.0
# 22453  2020-06-03T16:15:20  2020-11-23T21:32:54      19841715.0
# 22454  2020-07-14T13:40:07  2020-11-23T21:32:54      18306968.0
# 22455  2020-07-18T23:35:02  2020-11-23T21:32:54      14054356.0
# 22456  2020-07-23T07:13:04  2020-11-23T21:32:54        217639.0
#
#                          organizationName    siteId     siteName  \
# 0                   GPM Satellite Mission   35785.0  18SUJ105472
# 1                   GPM Satellite Mission   35785.0  18SUJ105472
# 2                   GPM Satellite Mission   35785.0  18SUJ105472
# 3                   GPM Satellite Mission   35785.0  18SUJ105472
# 4                   GPM Satellite Mission   35785.0  18SUJ105472
# ...                                   ...       ...          ...
# 22452                     lycee Thilmakha  200580.0  28PCB553673
# 22453          Madagascar Citizen Science  201123.0  38KQE645064
# 22454  Taiwan Partnership Citizen Science  208771.0  51RUH399684
# 22455                     lycee Thilmakha  209660.0  28PDB055429
# 22456  Suranaree University of Technology  210372.0  47PNK984553
#
#          countryName  ... mosquitohabitatmapperComments  \
# 0      United States  ...                          None
# 1      United States  ...                          None
# 2      United States  ...                          None
# 3      United States  ...                          None
# 4      United States  ...                          None
# ...              ...  ...                           ...
# 22452        Senegal  ...                          None
# 22453           None  ...                          None
# 22454           None  ...                          None
# 22455        Senegal  ...                          None
# 22456       Thailand  ...                          None
#
#        mosquitohabitatmapperMosquitoPupae  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 22452                                True
# 22453                               False
# 22454                                True
# 22455                                True
# 22456                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0      https://data.globe.gov/system/photos/2018/11/2...
# 1      https://data.globe.gov/system/photos/2019/04/0...
# 2      https://data.globe.gov/system/photos/2019/04/0...
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4      https://data.globe.gov/system/photos/2019/08/0...
# ...                                                  ...
# 22452  https://data.globe.gov/system/photos/2020/05/3...
# 22453  https://data.globe.gov/system/photos/2020/05/2...
# 22454                                               None
# 22455  https://data.globe.gov/system/photos/2020/05/3...
# 22456                                               None
#
#        mosquitohabitatmapperDataSource  \
# 0                   GLOBE Observer App
# 1                   GLOBE Observer App
# 2                   GLOBE Observer App
# 3                   GLOBE Observer App
# 4                   GLOBE Observer App
# ...                                ...
# 22452               GLOBE Observer App
# 22453               GLOBE Observer App
# 22454               GLOBE Observer App
# 22455               GLOBE Observer App
# 22456               GLOBE Observer App
#
#              mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4                                                   None
# ...                                                  ...
# 22452  https://data.globe.gov/system/photos/2020/05/3...
# 22453                                               None
# 22454  https://data.globe.gov/system/photos/2020/05/0...
# 22455                                               None
# 22456                                               None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                      39.2538
# 1                                      39.2535
# 2                                      39.2536
# 3                                      39.2542
# 4                                      39.2536
# ...                                        ...
# 22452                                  15.0778
# 22453                                 -18.9168
# 22454                                  25.0235
# 22455                                  14.8591
# 22456                                   8.6420
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 0                                       None
# 1                                   identify
# 2                                   identify
# 3                     identify-siphon-pecten
# 4                                   identify
# ...                                      ...
# 22452                  identify-siphon-shape
# 22453                               identify
# 22454                    identify-basal-tuft
# 22455                    identify-aedes-tuft
# 22456                    identify-photo-prep
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                    container: artificial
# 1                    container: artificial
# 2                    container: artificial
# 3                    container: artificial
# 4                    container: artificial
# ...                                    ...
# 22452                container: artificial
# 22453                container: artificial
# 22454                container: artificial
# 22455                container: artificial
# 22456                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                           5188.0
# 1                                          10365.0
# 2                                          10360.0
# 3                                          12424.0
# 4                                          14822.0
# ...                                            ...
# 22452                                      22772.0
# 22453                                      22806.0
# 22454                                      24654.0
# 22455                                      24880.0
# 22456                                      25049.0
#
#        mosquitohabitatmapperMeasurementLongitude
# 0                                       -77.1959
# 1                                       -77.1960
# 2                                       -77.1956
# 3                                       -77.1962
# 4                                       -77.1957
# ...                                          ...
# 22452                                   -16.3463
# 22453                                    47.5121
# 22454                                   121.4134
# 22455                                   -15.8784
# 22456                                    99.8951
#
# [19982 rows x 38 columns]

# %% [markdown]
# # Step 5 -- Event Photo Downloading Script
#
# The following script downloads photos associated with possible mosquito mapper training events (identified in the previous script) in addition to other information to help a human identify later identify which groups were truly training events. This can also aid in future research exploring these training events.
#
# The procedure is as follows:
# - Obtains identified training events
# - Generates a CSV of these events for future reference
# - For each group, creates a subfolder and performs the following tasks:
#     - Downloads all the photos collected in the suspected group
#     - Creates a CSV containing all the photo file names, urls, and attributions
#     - Creates a CSV containing all the entries for that group

# %%
# Identifies groups
suspect_groups = suspect_df.groupby(by = ['measuredDate','latitude','mosquitohabitatmapperWaterSource','siteName','longitude'])

# %%
# Creates a groups dataset
groups_list = []
groups_data = pd.DataFrame()
for group, df in suspect_groups:
    groups_list.append(str(group))
    new_df = df.copy(True)
    new_df["Group Name"] = str(group)
    groups_data = groups_data.append(new_df, ignore_index = True)
groups_df= pd.DataFrame(groups_list, columns=["Group"])
groups_data.to_csv("Group Data.csv")
groups_df
# Out:
#                                                  Group
# 0    ('2017-08-30', 8.643907, 'pond', '47PNK987556'...
# 1    ('2018-06-08', -5.193823, 'fountain or bird ba...
# 2    ('2018-06-13', -5.193823, 'fountain or bird ba...
# 3    ('2018-06-15', -4.911338, 'other', '17MNQ73457...
# 4    ('2018-07-30', 7.812627, 'other', '47NPJ040637...
# ..                                                 ...
# 116  ('2020-01-27', 15.037919, 'cement, metal or pl...
# 117  ('2020-01-27', 18.01673, 'well or cistern', '4...
# 118  ('2020-02-20', 15.040585, 'cement, metal or pl...
# 119  ('2020-03-04', 8.643917, 'cement, metal or pla...
# 120  ('2020-05-30', 15.077131, 'cement, metal or pl...
#
# [121 rows x 1 columns]

# %%
# Creates a results directory if it doesn't already exist
if not os.path.isdir("Results"):
    os.mkdir("Results")
        
# Writes groups' data to a csv in that folder
groups_df.to_csv("Results/groups.csv")

# %%
# Downloads a given photo with important metadata
def download_picture(url, directory):
    def get_picture(file_name):
        downloaded_obj = requests.get(url, allow_redirects=True)
        parent_dir = os.path.join(directory, file_name)
        with open(parent_dir, "wb") as file:
            file.write(downloaded_obj.content)

    if "https://" in url:
        photo_id = re.search(r'(?<=\d\d\d\d\/\d\d\/\d\d\/).*(?=\/)', url).group(0)
        file_name = f"{photo_id}.jpg".replace(":","-")
        get_picture(file_name)
        temp_dict = {
                        "image_name" : [file_name],
                        "origin" : "GLOBE",
                        "link" : [url],
                        "attribution" : "GLOBE",
                        "license" : "Creative Commons - share adapt attribute"
                    }
        return pd.DataFrame.from_dict(temp_dict)

# %%
# Photodownloading script for suspect groups
for data, group in suspect_groups:
    pics = pd.DataFrame()
    name = f"{data[0]}-{data[2]}-{data[3]}".replace("/", "-")
    dir_name = f"Results/{name}"
    if not os.path.isdir(dir_name):
        os.mkdir(dir_name)
    group_water_source = group["mosquitohabitatmapperWaterSourcePhotoUrls"].dropna().tolist()
    group_abdomen = group["mosquitohabitatmapperAbdomenCloseupPhotoUrls"].dropna().tolist()
    group_larvae = group["mosquitohabitatmapperLarvaFullBodyPhotoUrls"].dropna().tolist()
    group_urls = group_water_source + group_abdomen + group_larvae
    for urls in group_urls:
        if urls:
            urls = urls.split(";")
            for url in urls:
                pics = pics.append(download_picture(url, dir_name), ignore_index = True)
                
    pics.to_csv(f"{dir_name}/pictures.csv")
    group.to_csv(f"{dir_name}/data.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-f0c21611a523> in <module>
#      14             urls = urls.split(";")
#      15             for url in urls:
# ---> 16                 pics = pics.append(download_picture(url, dir_name), ignore_index = True)
#      17
#      18     pics.to_csv(f"{dir_name}/pictures.csv")
#
# <ipython-input-17-7565252a0b64> in download_picture(url, directory)
#       9         photo_id = re.search(r'(?<=\d\d\d\d\/\d\d\/\d\d\/).*(?=\/)', url).group(0)
#      10         file_name = f"{photo_id}.jpg".replace(":","-")
# ---> 11         get_picture(file_name)
#      12         temp_dict = {
#      13                         "image_name" : [file_name],
#
# <ipython-input-17-7565252a0b64> in get_picture(file_name)
#       1 def download_picture(url, directory):
#       2     def get_picture(file_name):
# ----> 3         downloaded_obj = requests.get(url, allow_redirects=True)
#       4         parent_dir = os.path.join(directory, file_name)
#       5         with open(parent_dir, "wb") as file:
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# ~\anaconda3\lib\site-packages\requests\models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     562         else:
#     563             while not is_fp_closed(self._fp):
# --> 564                 data = self.read(amt=amt, decode_content=decode_content)
#     565
#     566                 if data:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     499         # connection, and the user is reading more bytes than will be provided
#     500         # (for example, reading in 1k chunks)
# --> 501         n = self.fp.readinto(b)
#     502         if not n and b:
#     503             # Ideally, we would raise IncompleteRead if the content-length
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:

# %% [markdown]
# # Step 6 -- Clean Photo Download
#
# This script downloads all of the photos from the clean dataset into a "Clean Data" folder.

# %%
if not os.path.isdir("Clean Data"):
    os.mkdir("Clean Data")
        
# photodownloading script for clean data download
pics = pd.DataFrame()
water_source = df["mosquitohabitatmapperWaterSourcePhotoUrls"].dropna().tolist()
abdomen = df["mosquitohabitatmapperAbdomenCloseupPhotoUrls"].dropna().tolist()
larvae = df["mosquitohabitatmapperLarvaFullBodyPhotoUrls"].dropna().tolist()
url_list = water_source + abdomen + larvae
for urls in url_list:
    if urls:
        urls = urls.split(";")
        for url in urls:
            pics = pics.append(download_picture(url, "Clean Data"), ignore_index = True)
                
pics.to_csv(f"Clean Data/pictures.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-77716f2ea9d2> in <module>
#      12         urls = urls.split(";")
#      13         for url in urls:
# ---> 14             pics = pics.append(download_picture(url, "Clean Data"), ignore_index = True)
#      15
#      16 pics.to_csv(f"Clean Data/pictures.csv")
#
# <ipython-input-17-7565252a0b64> in download_picture(url, directory)
#       9         photo_id = re.search(r'(?<=\d\d\d\d\/\d\d\/\d\d\/).*(?=\/)', url).group(0)
#      10         file_name = f"{photo_id}.jpg".replace(":","-")
# ---> 11         get_picture(file_name)
#      12         temp_dict = {
#      13                         "image_name" : [file_name],
#
# <ipython-input-17-7565252a0b64> in get_picture(file_name)
#       1 def download_picture(url, directory):
#       2     def get_picture(file_name):
# ----> 3         downloaded_obj = requests.get(url, allow_redirects=True)
#       4         parent_dir = os.path.join(directory, file_name)
#       5         with open(parent_dir, "wb") as file:
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# ~\anaconda3\lib\site-packages\requests\models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     562         else:
#     563             while not is_fp_closed(self._fp):
# --> 564                 data = self.read(amt=amt, decode_content=decode_content)
#     565
#     566                 if data:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     499         # connection, and the user is reading more bytes than will be provided
#     500         # (for example, reading in 1k chunks)
# --> 501         n = self.fp.readinto(b)
#     502         if not n and b:
#     503             # Ideally, we would raise IncompleteRead if the content-length
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:
