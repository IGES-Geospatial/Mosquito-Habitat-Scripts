# %% [markdown]
# # API Downloading Data Procedure:
#
# Downloading data follows these steps:
# - Request the non GEOJSON data from the GLOBE API
# - Get the results from the JSON and pass it into a pandas dataframe
# - Unpack the "data" entry
# - Merge the data onto the original dataframe
# - Remove the "data" entry from the original dataframe

# %%
import pandas as pd
import requests

start_date = "2017-05-29"
end_date = "2020-05-31"
url = f"https://api.globe.gov/search/v1/measurement/protocol/measureddate/?protocols=mosquito_habitat_mapper&startdate={start_date}&enddate={end_date}&geojson=FALSE&sample=FALSE"

# downloads data from the GLOBE API
response = requests.get(url)

# Converts data into a useable dataframe
data = response.json()["results"]
        
df = pd.DataFrame(data)

# unpacking and joining the data entry
data_df = pd.DataFrame(df["data"].to_dict())
data_df = data_df.transpose()
df = df.join(data_df)
df.drop(["data"], axis=1, inplace = True)

# display the dataframe
df
# Out:
#                       protocol measuredDate           createDate  \
# 0      mosquito_habitat_mapper   2018-11-25  2020-01-25T18:09:52
# 1      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 2      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 3      mosquito_habitat_mapper   2019-05-29  2020-01-25T18:29:36
# 4      mosquito_habitat_mapper   2019-08-04  2020-01-25T18:45:20
# ...                        ...          ...                  ...
# 22449  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 22450  mosquito_habitat_mapper   2020-05-29  2020-06-03T07:30:03
# 22451  mosquito_habitat_mapper   2020-05-06  2020-07-14T08:40:05
# 22452  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
# 22453  mosquito_habitat_mapper   2020-01-29  2020-07-23T07:13:04
#
#                 updateDate          publishDate  organizationId  \
# 0      2020-01-25T18:09:52  2020-02-14T20:29:11      13063641.0
# 1      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 2      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 3      2020-01-25T18:29:36  2020-03-20T22:19:48      13063641.0
# 4      2020-01-25T18:45:20  2020-03-20T22:19:48      13063641.0
# ...                    ...                  ...             ...
# 22449  2020-05-30T19:30:02  2020-09-05T21:23:09      14054356.0
# 22450  2020-06-03T16:15:20  2020-09-05T21:23:09      19841715.0
# 22451  2020-07-14T13:40:07  2020-09-05T21:23:09      18306968.0
# 22452  2020-07-18T23:35:02  2020-09-05T21:23:09      14054356.0
# 22453  2020-07-23T07:13:04  2020-09-05T21:23:09        217639.0
#
#                          organizationName  siteId     siteName    countryName  \
# 0                   GPM Satellite Mission   35785  18SUJ105472  United States
# 1                   GPM Satellite Mission   35785  18SUJ105472  United States
# 2                   GPM Satellite Mission   35785  18SUJ105472  United States
# 3                   GPM Satellite Mission   35785  18SUJ105472  United States
# 4                   GPM Satellite Mission   35785  18SUJ105472  United States
# ...                                   ...     ...          ...            ...
# 22449                     lycee Thilmakha  200580  28PCB553673        Senegal
# 22450          Madagascar Citizen Science  201123  38KQE645064           None
# 22451  Taiwan Partnership Citizen Science  208771  51RUH399684           None
# 22452                     lycee Thilmakha  209660  28PDB055429        Senegal
# 22453  Suranaree University of Technology  210372  47PNK984553       Thailand
#
#        ... mosquitohabitatmapperComments  mosquitohabitatmapperMosquitoPupae  \
# 0      ...                          None                               False
# 1      ...                          None                               False
# 2      ...                          None                               False
# 3      ...                          None                               False
# 4      ...                          None                               False
# ...    ...                           ...                                 ...
# 22449  ...                          None                                True
# 22450  ...                          None                               False
# 22451  ...                          None                                True
# 22452  ...                          None                                True
# 22453  ...                          None                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0      https://data.globe.gov/system/photos/2018/11/2...
# 1      https://data.globe.gov/system/photos/2019/04/0...
# 2      https://data.globe.gov/system/photos/2019/04/0...
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4      https://data.globe.gov/system/photos/2019/08/0...
# ...                                                  ...
# 22449  https://data.globe.gov/system/photos/2020/05/3...
# 22450  https://data.globe.gov/system/photos/2020/05/2...
# 22451                                               None
# 22452  https://data.globe.gov/system/photos/2020/05/3...
# 22453                                               None
#
#        mosquitohabitatmapperDataSource  \
# 0                   GLOBE Observer App
# 1                   GLOBE Observer App
# 2                   GLOBE Observer App
# 3                   GLOBE Observer App
# 4                   GLOBE Observer App
# ...                                ...
# 22449               GLOBE Observer App
# 22450               GLOBE Observer App
# 22451               GLOBE Observer App
# 22452               GLOBE Observer App
# 22453               GLOBE Observer App
#
#              mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4                                                   None
# ...                                                  ...
# 22449  https://data.globe.gov/system/photos/2020/05/3...
# 22450                                               None
# 22451  https://data.globe.gov/system/photos/2020/05/0...
# 22452                                               None
# 22453                                               None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                      39.2538
# 1                                      39.2535
# 2                                      39.2536
# 3                                      39.2542
# 4                                      39.2536
# ...                                        ...
# 22449                                  15.0777
# 22450                                 -18.9168
# 22451                                  25.0235
# 22452                                  14.8591
# 22453                                    8.642
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 0                                       None
# 1                                   identify
# 2                                   identify
# 3                     identify-siphon-pecten
# 4                                   identify
# ...                                      ...
# 22449                  identify-siphon-shape
# 22450                               identify
# 22451                    identify-basal-tuft
# 22452                    identify-aedes-tuft
# 22453                    identify-photo-prep
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                    container: artificial
# 1                    container: artificial
# 2                    container: artificial
# 3                    container: artificial
# 4                    container: artificial
# ...                                    ...
# 22449                container: artificial
# 22450                container: artificial
# 22451                container: artificial
# 22452                container: artificial
# 22453                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                             5188
# 1                                            10365
# 2                                            10360
# 3                                            12424
# 4                                            14822
# ...                                            ...
# 22449                                        22776
# 22450                                        22806
# 22451                                        24654
# 22452                                        24880
# 22453                                        25049
#
#       mosquitohabitatmapperMeasurementLongitude
# 0                                      -77.1959
# 1                                       -77.196
# 2                                      -77.1956
# 3                                      -77.1962
# 4                                      -77.1957
# ...                                         ...
# 22449                                  -16.3463
# 22450                                   47.5121
# 22451                                   121.413
# 22452                                  -15.8784
# 22453                                   99.8951
#
# [22454 rows x 38 columns]

# %% [markdown]
# # CSV Downloading
#
# This cell allows for the option of using mosquito mapper data from CSV Files.
#
# This enables an analysis of different subsets of the total mosquito mapper data (this will overwrite data downloaded from the API).

# %%
filename = "Africa.csv"
df = pd.read_csv(filename)
df

# %% [markdown]
# # GeoLocational Data Cleaning Procedure:
# Here are the conditions in which the data is removed:
# - The Site Latitude and Longitude match the ones measured by the GPS
# - The GPS Measurements are integers

# %%
import numpy as np

def geolocational_filter(gps_lat, gps_lon, recorded_lat, recorded_lon):
    return ((recorded_lat == gps_lat and 
        recorded_lon == gps_lon) or
        isinstance(gps_lat, int) or
        isinstance(gps_lon, int)
        )

vectorized_filter = np.vectorize(geolocational_filter)
bad_data = vectorized_filter(df["mosquitohabitatmapperMeasurementLatitude"].to_numpy(),
                             df["mosquitohabitatmapperMeasurementLongitude"].to_numpy(),
                             df["latitude"].to_numpy(),
                             df["longitude"].to_numpy()
                            )
df = df[~bad_data]
df = df.reset_index().drop(["index"], axis = 1)
# displaying the dataframe
df
# Out:
#                       protocol measuredDate           createDate  \
# 0      mosquito_habitat_mapper   2018-11-25  2020-01-25T18:09:52
# 1      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 2      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 3      mosquito_habitat_mapper   2019-05-29  2020-01-25T18:29:36
# 4      mosquito_habitat_mapper   2019-08-04  2020-01-25T18:45:20
# ...                        ...          ...                  ...
# 19274  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 19275  mosquito_habitat_mapper   2020-05-29  2020-06-03T07:30:03
# 19276  mosquito_habitat_mapper   2020-05-06  2020-07-14T08:40:05
# 19277  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
# 19278  mosquito_habitat_mapper   2020-01-29  2020-07-23T07:13:04
#
#                 updateDate          publishDate  organizationId  \
# 0      2020-01-25T18:09:52  2020-02-14T20:29:11      13063641.0
# 1      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 2      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 3      2020-01-25T18:29:36  2020-03-20T22:19:48      13063641.0
# 4      2020-01-25T18:45:20  2020-03-20T22:19:48      13063641.0
# ...                    ...                  ...             ...
# 19274  2020-05-30T19:30:02  2020-09-05T21:23:09      14054356.0
# 19275  2020-06-03T16:15:20  2020-09-05T21:23:09      19841715.0
# 19276  2020-07-14T13:40:07  2020-09-05T21:23:09      18306968.0
# 19277  2020-07-18T23:35:02  2020-09-05T21:23:09      14054356.0
# 19278  2020-07-23T07:13:04  2020-09-05T21:23:09        217639.0
#
#                          organizationName  siteId     siteName    countryName  \
# 0                   GPM Satellite Mission   35785  18SUJ105472  United States
# 1                   GPM Satellite Mission   35785  18SUJ105472  United States
# 2                   GPM Satellite Mission   35785  18SUJ105472  United States
# 3                   GPM Satellite Mission   35785  18SUJ105472  United States
# 4                   GPM Satellite Mission   35785  18SUJ105472  United States
# ...                                   ...     ...          ...            ...
# 19274                     lycee Thilmakha  200580  28PCB553673        Senegal
# 19275          Madagascar Citizen Science  201123  38KQE645064           None
# 19276  Taiwan Partnership Citizen Science  208771  51RUH399684           None
# 19277                     lycee Thilmakha  209660  28PDB055429        Senegal
# 19278  Suranaree University of Technology  210372  47PNK984553       Thailand
#
#        ... mosquitohabitatmapperComments  mosquitohabitatmapperMosquitoPupae  \
# 0      ...                          None                               False
# 1      ...                          None                               False
# 2      ...                          None                               False
# 3      ...                          None                               False
# 4      ...                          None                               False
# ...    ...                           ...                                 ...
# 19274  ...                          None                                True
# 19275  ...                          None                               False
# 19276  ...                          None                                True
# 19277  ...                          None                                True
# 19278  ...                          None                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0      https://data.globe.gov/system/photos/2018/11/2...
# 1      https://data.globe.gov/system/photos/2019/04/0...
# 2      https://data.globe.gov/system/photos/2019/04/0...
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4      https://data.globe.gov/system/photos/2019/08/0...
# ...                                                  ...
# 19274  https://data.globe.gov/system/photos/2020/05/3...
# 19275  https://data.globe.gov/system/photos/2020/05/2...
# 19276                                               None
# 19277  https://data.globe.gov/system/photos/2020/05/3...
# 19278                                               None
#
#        mosquitohabitatmapperDataSource  \
# 0                   GLOBE Observer App
# 1                   GLOBE Observer App
# 2                   GLOBE Observer App
# 3                   GLOBE Observer App
# 4                   GLOBE Observer App
# ...                                ...
# 19274               GLOBE Observer App
# 19275               GLOBE Observer App
# 19276               GLOBE Observer App
# 19277               GLOBE Observer App
# 19278               GLOBE Observer App
#
#              mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4                                                   None
# ...                                                  ...
# 19274  https://data.globe.gov/system/photos/2020/05/3...
# 19275                                               None
# 19276  https://data.globe.gov/system/photos/2020/05/0...
# 19277                                               None
# 19278                                               None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                      39.2538
# 1                                      39.2535
# 2                                      39.2536
# 3                                      39.2542
# 4                                      39.2536
# ...                                        ...
# 19274                                  15.0777
# 19275                                 -18.9168
# 19276                                  25.0235
# 19277                                  14.8591
# 19278                                    8.642
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 0                                       None
# 1                                   identify
# 2                                   identify
# 3                     identify-siphon-pecten
# 4                                   identify
# ...                                      ...
# 19274                  identify-siphon-shape
# 19275                               identify
# 19276                    identify-basal-tuft
# 19277                    identify-aedes-tuft
# 19278                    identify-photo-prep
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                    container: artificial
# 1                    container: artificial
# 2                    container: artificial
# 3                    container: artificial
# 4                    container: artificial
# ...                                    ...
# 19274                container: artificial
# 19275                container: artificial
# 19276                container: artificial
# 19277                container: artificial
# 19278                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                             5188
# 1                                            10365
# 2                                            10360
# 3                                            12424
# 4                                            14822
# ...                                            ...
# 19274                                        22776
# 19275                                        22806
# 19276                                        24654
# 19277                                        24880
# 19278                                        25049
#
#       mosquitohabitatmapperMeasurementLongitude
# 0                                      -77.1959
# 1                                       -77.196
# 2                                      -77.1956
# 3                                      -77.1962
# 4                                      -77.1957
# ...                                         ...
# 19274                                  -16.3463
# 19275                                   47.5121
# 19276                                   121.413
# 19277                                  -15.8784
# 19278                                   99.8951
#
# [19279 rows x 38 columns]

# %%
# writes the filtered data to a csv
df.to_csv("Geolocation.csv")

# %% [markdown]
# # Suspected Training Event Removal
#
# The procedure that is used is as follows:
# - Mosquito Entries that share the same measured date, site latitude, site longitude, siteName, and water source are grouped together
# - These groups are then filtered resulting in identifying groups of a size greater than a specified threshold.
# - Then these identified groups are removed from the overall dataframe
# - The dataframe containing the groups and the clean dataframe are then written into csv files.

# %% [markdown]
# ## Threshold Variable
#
# The threshold variable is the minimum number of duplicate entries (exclusive) that are needed for the the group of entries to be classified as an event.
#
# Set the threshold value and then run the following cells

# %%
threshold = 10

# %%
# groups / filters suspected events
suspect_df = df.groupby(by=['measuredDate','latitude','mosquitohabitatmapperWaterSource','siteName','longitude']).filter(lambda x: len(x) > threshold)

# writes the entries to a CSV
suspect_df.to_csv("Possible Events.csv")       

# displays the suspected entries
suspect_df
# Out:
#                       protocol measuredDate           createDate  \
# 469    mosquito_habitat_mapper   2018-08-17  2020-01-25T18:02:43
# 473    mosquito_habitat_mapper   2018-08-17  2020-01-25T18:02:43
# 475    mosquito_habitat_mapper   2018-08-17  2020-01-25T18:02:43
# 476    mosquito_habitat_mapper   2018-08-17  2020-01-25T18:02:43
# 481    mosquito_habitat_mapper   2018-08-17  2020-01-25T18:02:43
# ...                        ...          ...                  ...
# 19154  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
# 19156  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
# 19157  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
# 19158  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
# 19159  mosquito_habitat_mapper   2020-01-20  2020-04-20T07:30:02
#
#                 updateDate          publishDate  organizationId  \
# 469    2020-01-25T18:02:43  2020-02-14T20:29:11      17615655.0
# 473    2020-01-25T18:02:43  2020-02-14T20:29:11      17615655.0
# 475    2020-01-25T18:02:43  2020-02-14T20:29:11      17615655.0
# 476    2020-01-25T18:02:43  2020-02-14T20:29:11      17615655.0
# 481    2020-01-25T18:02:43  2020-02-14T20:29:11      17615655.0
# ...                    ...                  ...             ...
# 19154  2020-04-20T07:31:25  2020-09-05T21:23:09      17615655.0
# 19156  2020-04-20T07:31:25  2020-09-05T21:23:09      17615655.0
# 19157  2020-04-20T07:31:25  2020-09-05T21:23:09      17615655.0
# 19158  2020-04-20T07:31:25  2020-09-05T21:23:09      17615655.0
# 19159  2020-04-20T07:31:25  2020-09-05T21:23:09      17615655.0
#
#                organizationName  siteId     siteName countryName  ...  \
# 469    Thailand Citizen Science   97680  47PNK988555        None  ...
# 473    Thailand Citizen Science   97680  47PNK988555        None  ...
# 475    Thailand Citizen Science   97680  47PNK988555        None  ...
# 476    Thailand Citizen Science   97680  47PNK988555        None  ...
# 481    Thailand Citizen Science   97680  47PNK988555        None  ...
# ...                         ...     ...          ...         ...  ...
# 19154  Thailand Citizen Science  196380  47QMB636059        None  ...
# 19156  Thailand Citizen Science  196380  47QMB636059        None  ...
# 19157  Thailand Citizen Science  196380  47QMB636059        None  ...
# 19158  Thailand Citizen Science  196380  47QMB636059        None  ...
# 19159  Thailand Citizen Science  196380  47QMB636059        None  ...
#
#       mosquitohabitatmapperComments  mosquitohabitatmapperMosquitoPupae  \
# 469                            None                                None
# 473                            None                                None
# 475                            None                                None
# 476                            None                                None
# 481                            None                                None
# ...                             ...                                 ...
# 19154                          None                               False
# 19156                          None                               False
# 19157                          None                               False
# 19158                          None                               False
# 19159                          None                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 469                                             rejected
# 473    https://data.globe.gov/system/photos/2018/08/1...
# 475    https://data.globe.gov/system/photos/2018/08/1...
# 476                                             rejected
# 481    https://data.globe.gov/system/photos/2018/08/1...
# ...                                                  ...
# 19154                                               None
# 19156                                               None
# 19157                                               None
# 19158                                               None
# 19159                                               None
#
#        mosquitohabitatmapperDataSource  \
# 469                 GLOBE Observer App
# 473                 GLOBE Observer App
# 475                 GLOBE Observer App
# 476                 GLOBE Observer App
# 481                 GLOBE Observer App
# ...                                ...
# 19154               GLOBE Observer App
# 19156               GLOBE Observer App
# 19157               GLOBE Observer App
# 19158               GLOBE Observer App
# 19159               GLOBE Observer App
#
#        mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 469                                           None
# 473                                           None
# 475                                           None
# 476                                           None
# 481                                           None
# ...                                            ...
# 19154                                         None
# 19156                                         None
# 19157                                         None
# 19158                                         None
# 19159                                         None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 469                                     8.6437
# 473                                     8.6436
# 475                                     8.6436
# 476                                     8.6436
# 481                                     8.6437
# ...                                        ...
# 19154                                  19.0461
# 19156                                  19.0461
# 19157                                  19.0461
# 19158                                  19.0461
# 19159                                  19.0461
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 469                                     None
# 473                                     None
# 475                                 identify
# 476                                     None
# 481                                     None
# ...                                      ...
# 19154                               identify
# 19156                               identify
# 19157                               identify
# 19158                               identify
# 19159                               identify
#
#       mosquitohabitatmapperWaterSourceType  \
# 469                 still: lake/pond/swamp
# 473                 still: lake/pond/swamp
# 475                 still: lake/pond/swamp
# 476                 still: lake/pond/swamp
# 481                 still: lake/pond/swamp
# ...                                    ...
# 19154                container: artificial
# 19156                container: artificial
# 19157                container: artificial
# 19158                container: artificial
# 19159                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 469                                           3856
# 473                                           3858
# 475                                           3877
# 476                                           3855
# 481                                           4044
# ...                                            ...
# 19154                                        22321
# 19156                                        22335
# 19157                                        22336
# 19158                                        22338
# 19159                                        22340
#
#       mosquitohabitatmapperMeasurementLongitude
# 469                                     99.8984
# 473                                     99.8985
# 475                                     99.8983
# 476                                     99.8985
# 481                                     99.8981
# ...                                         ...
# 19154                                   98.6549
# 19156                                   98.6549
# 19157                                    98.655
# 19158                                    98.655
# 19159                                    98.655
#
# [2369 rows x 38 columns]

# %%
suspect_mask = df.isin(suspect_df)

clean_df = df[~suspect_mask].dropna(how = "all")

clean_df.to_csv("Clean CSV.csv")

# display's cleaned data
clean_df
# Out:
#                       protocol measuredDate           createDate  \
# 0      mosquito_habitat_mapper   2018-11-25  2020-01-25T18:09:52
# 1      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 2      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 3      mosquito_habitat_mapper   2019-05-29  2020-01-25T18:29:36
# 4      mosquito_habitat_mapper   2019-08-04  2020-01-25T18:45:20
# ...                        ...          ...                  ...
# 19274  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 19275  mosquito_habitat_mapper   2020-05-29  2020-06-03T07:30:03
# 19276  mosquito_habitat_mapper   2020-05-06  2020-07-14T08:40:05
# 19277  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
# 19278  mosquito_habitat_mapper   2020-01-29  2020-07-23T07:13:04
#
#                 updateDate          publishDate  organizationId  \
# 0      2020-01-25T18:09:52  2020-02-14T20:29:11      13063641.0
# 1      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 2      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 3      2020-01-25T18:29:36  2020-03-20T22:19:48      13063641.0
# 4      2020-01-25T18:45:20  2020-03-20T22:19:48      13063641.0
# ...                    ...                  ...             ...
# 19274  2020-05-30T19:30:02  2020-09-05T21:23:09      14054356.0
# 19275  2020-06-03T16:15:20  2020-09-05T21:23:09      19841715.0
# 19276  2020-07-14T13:40:07  2020-09-05T21:23:09      18306968.0
# 19277  2020-07-18T23:35:02  2020-09-05T21:23:09      14054356.0
# 19278  2020-07-23T07:13:04  2020-09-05T21:23:09        217639.0
#
#                          organizationName    siteId     siteName  \
# 0                   GPM Satellite Mission   35785.0  18SUJ105472
# 1                   GPM Satellite Mission   35785.0  18SUJ105472
# 2                   GPM Satellite Mission   35785.0  18SUJ105472
# 3                   GPM Satellite Mission   35785.0  18SUJ105472
# 4                   GPM Satellite Mission   35785.0  18SUJ105472
# ...                                   ...       ...          ...
# 19274                     lycee Thilmakha  200580.0  28PCB553673
# 19275          Madagascar Citizen Science  201123.0  38KQE645064
# 19276  Taiwan Partnership Citizen Science  208771.0  51RUH399684
# 19277                     lycee Thilmakha  209660.0  28PDB055429
# 19278  Suranaree University of Technology  210372.0  47PNK984553
#
#          countryName  ... mosquitohabitatmapperComments  \
# 0      United States  ...                          None
# 1      United States  ...                          None
# 2      United States  ...                          None
# 3      United States  ...                          None
# 4      United States  ...                          None
# ...              ...  ...                           ...
# 19274        Senegal  ...                          None
# 19275           None  ...                          None
# 19276           None  ...                          None
# 19277        Senegal  ...                          None
# 19278       Thailand  ...                          None
#
#        mosquitohabitatmapperMosquitoPupae  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 19274                                True
# 19275                               False
# 19276                                True
# 19277                                True
# 19278                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0      https://data.globe.gov/system/photos/2018/11/2...
# 1      https://data.globe.gov/system/photos/2019/04/0...
# 2      https://data.globe.gov/system/photos/2019/04/0...
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4      https://data.globe.gov/system/photos/2019/08/0...
# ...                                                  ...
# 19274  https://data.globe.gov/system/photos/2020/05/3...
# 19275  https://data.globe.gov/system/photos/2020/05/2...
# 19276                                               None
# 19277  https://data.globe.gov/system/photos/2020/05/3...
# 19278                                               None
#
#        mosquitohabitatmapperDataSource  \
# 0                   GLOBE Observer App
# 1                   GLOBE Observer App
# 2                   GLOBE Observer App
# 3                   GLOBE Observer App
# 4                   GLOBE Observer App
# ...                                ...
# 19274               GLOBE Observer App
# 19275               GLOBE Observer App
# 19276               GLOBE Observer App
# 19277               GLOBE Observer App
# 19278               GLOBE Observer App
#
#              mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4                                                   None
# ...                                                  ...
# 19274  https://data.globe.gov/system/photos/2020/05/3...
# 19275                                               None
# 19276  https://data.globe.gov/system/photos/2020/05/0...
# 19277                                               None
# 19278                                               None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                      39.2538
# 1                                      39.2535
# 2                                      39.2536
# 3                                      39.2542
# 4                                      39.2536
# ...                                        ...
# 19274                                  15.0777
# 19275                                 -18.9168
# 19276                                  25.0235
# 19277                                  14.8591
# 19278                                    8.642
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 0                                       None
# 1                                   identify
# 2                                   identify
# 3                     identify-siphon-pecten
# 4                                   identify
# ...                                      ...
# 19274                  identify-siphon-shape
# 19275                               identify
# 19276                    identify-basal-tuft
# 19277                    identify-aedes-tuft
# 19278                    identify-photo-prep
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                    container: artificial
# 1                    container: artificial
# 2                    container: artificial
# 3                    container: artificial
# 4                    container: artificial
# ...                                    ...
# 19274                container: artificial
# 19275                container: artificial
# 19276                container: artificial
# 19277                container: artificial
# 19278                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                             5188
# 1                                            10365
# 2                                            10360
# 3                                            12424
# 4                                            14822
# ...                                            ...
# 19274                                        22776
# 19275                                        22806
# 19276                                        24654
# 19277                                        24880
# 19278                                        25049
#
#       mosquitohabitatmapperMeasurementLongitude
# 0                                      -77.1959
# 1                                       -77.196
# 2                                      -77.1956
# 3                                      -77.1962
# 4                                      -77.1957
# ...                                         ...
# 19274                                  -16.3463
# 19275                                   47.5121
# 19276                                   121.413
# 19277                                  -15.8784
# 19278                                   99.8951
#
# [16910 rows x 38 columns]

# %% [markdown]
# # Anomaly Removal
#
# The following two cells are designed to remove anomalous (overreporting) mosquito larvae from the dataset (e.g., reporting 1,000 mosquito larvae), and resolve any sets of reported ranges (e.g., 1-25) by choosing the upper bound.
#
# ## Anomaly Threshold Variable
# This is the threshold for the number of reported mosquito larvae that marks an entry as an anomaly. It will remove any entries that have mosquito larvae count observed higher than this number.

# %%
anomaly_threshold = 1000

# %%
import re
def to_int(x):
    try:
        return int(x)
    except ValueError:
        try:
            return int(re.sub(r".*-", "", x))
        except ValueError:
            return 0

vectorized_int = np.vectorize(to_int)
clean_df["mosquitohabitatmapperLarvaeCount"] = vectorized_int(clean_df["mosquitohabitatmapperLarvaeCount"].fillna(0).values)
clean_df = clean_df[clean_df["mosquitohabitatmapperLarvaeCount"] < anomaly_threshold]
clean_df.to_csv("CleanDF Updated.csv")

clean_df
# Out:
#                       protocol measuredDate           createDate  \
# 0      mosquito_habitat_mapper   2018-11-25  2020-01-25T18:09:52
# 1      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 2      mosquito_habitat_mapper   2019-04-07  2020-01-25T18:24:27
# 3      mosquito_habitat_mapper   2019-05-29  2020-01-25T18:29:36
# 4      mosquito_habitat_mapper   2019-08-04  2020-01-25T18:45:20
# ...                        ...          ...                  ...
# 19274  mosquito_habitat_mapper   2020-05-30  2020-05-30T18:25:03
# 19275  mosquito_habitat_mapper   2020-05-29  2020-06-03T07:30:03
# 19276  mosquito_habitat_mapper   2020-05-06  2020-07-14T08:40:05
# 19277  mosquito_habitat_mapper   2020-05-31  2020-07-18T23:35:02
# 19278  mosquito_habitat_mapper   2020-01-29  2020-07-23T07:13:04
#
#                 updateDate          publishDate  organizationId  \
# 0      2020-01-25T18:09:52  2020-02-14T20:29:11      13063641.0
# 1      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 2      2020-01-25T18:24:27  2020-03-20T22:19:48      13063641.0
# 3      2020-01-25T18:29:36  2020-03-20T22:19:48      13063641.0
# 4      2020-01-25T18:45:20  2020-03-20T22:19:48      13063641.0
# ...                    ...                  ...             ...
# 19274  2020-05-30T19:30:02  2020-09-05T21:23:09      14054356.0
# 19275  2020-06-03T16:15:20  2020-09-05T21:23:09      19841715.0
# 19276  2020-07-14T13:40:07  2020-09-05T21:23:09      18306968.0
# 19277  2020-07-18T23:35:02  2020-09-05T21:23:09      14054356.0
# 19278  2020-07-23T07:13:04  2020-09-05T21:23:09        217639.0
#
#                          organizationName    siteId     siteName  \
# 0                   GPM Satellite Mission   35785.0  18SUJ105472
# 1                   GPM Satellite Mission   35785.0  18SUJ105472
# 2                   GPM Satellite Mission   35785.0  18SUJ105472
# 3                   GPM Satellite Mission   35785.0  18SUJ105472
# 4                   GPM Satellite Mission   35785.0  18SUJ105472
# ...                                   ...       ...          ...
# 19274                     lycee Thilmakha  200580.0  28PCB553673
# 19275          Madagascar Citizen Science  201123.0  38KQE645064
# 19276  Taiwan Partnership Citizen Science  208771.0  51RUH399684
# 19277                     lycee Thilmakha  209660.0  28PDB055429
# 19278  Suranaree University of Technology  210372.0  47PNK984553
#
#          countryName  ... mosquitohabitatmapperComments  \
# 0      United States  ...                          None
# 1      United States  ...                          None
# 2      United States  ...                          None
# 3      United States  ...                          None
# 4      United States  ...                          None
# ...              ...  ...                           ...
# 19274        Senegal  ...                          None
# 19275           None  ...                          None
# 19276           None  ...                          None
# 19277        Senegal  ...                          None
# 19278       Thailand  ...                          None
#
#        mosquitohabitatmapperMosquitoPupae  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 19274                                True
# 19275                               False
# 19276                                True
# 19277                                True
# 19278                               False
#
#                mosquitohabitatmapperWaterSourcePhotoUrls  \
# 0      https://data.globe.gov/system/photos/2018/11/2...
# 1      https://data.globe.gov/system/photos/2019/04/0...
# 2      https://data.globe.gov/system/photos/2019/04/0...
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4      https://data.globe.gov/system/photos/2019/08/0...
# ...                                                  ...
# 19274  https://data.globe.gov/system/photos/2020/05/3...
# 19275  https://data.globe.gov/system/photos/2020/05/2...
# 19276                                               None
# 19277  https://data.globe.gov/system/photos/2020/05/3...
# 19278                                               None
#
#        mosquitohabitatmapperDataSource  \
# 0                   GLOBE Observer App
# 1                   GLOBE Observer App
# 2                   GLOBE Observer App
# 3                   GLOBE Observer App
# 4                   GLOBE Observer App
# ...                                ...
# 19274               GLOBE Observer App
# 19275               GLOBE Observer App
# 19276               GLOBE Observer App
# 19277               GLOBE Observer App
# 19278               GLOBE Observer App
#
#              mosquitohabitatmapperLarvaFullBodyPhotoUrls  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      https://data.globe.gov/system/photos/2019/05/2...
# 4                                                   None
# ...                                                  ...
# 19274  https://data.globe.gov/system/photos/2020/05/3...
# 19275                                               None
# 19276  https://data.globe.gov/system/photos/2020/05/0...
# 19277                                               None
# 19278                                               None
#
#       mosquitohabitatmapperMeasurementLatitude  \
# 0                                      39.2538
# 1                                      39.2535
# 2                                      39.2536
# 3                                      39.2542
# 4                                      39.2536
# ...                                        ...
# 19274                                  15.0777
# 19275                                 -18.9168
# 19276                                  25.0235
# 19277                                  14.8591
# 19278                                    8.642
#
#       mosquitohabitatmapperLastIdentifyStage  \
# 0                                       None
# 1                                   identify
# 2                                   identify
# 3                     identify-siphon-pecten
# 4                                   identify
# ...                                      ...
# 19274                  identify-siphon-shape
# 19275                               identify
# 19276                    identify-basal-tuft
# 19277                    identify-aedes-tuft
# 19278                    identify-photo-prep
#
#       mosquitohabitatmapperWaterSourceType  \
# 0                    container: artificial
# 1                    container: artificial
# 2                    container: artificial
# 3                    container: artificial
# 4                    container: artificial
# ...                                    ...
# 19274                container: artificial
# 19275                container: artificial
# 19276                container: artificial
# 19277                container: artificial
# 19278                container: artificial
#
#       mosquitohabitatmapperMosquitoHabitatMapperId  \
# 0                                             5188
# 1                                            10365
# 2                                            10360
# 3                                            12424
# 4                                            14822
# ...                                            ...
# 19274                                        22776
# 19275                                        22806
# 19276                                        24654
# 19277                                        24880
# 19278                                        25049
#
#       mosquitohabitatmapperMeasurementLongitude
# 0                                      -77.1959
# 1                                       -77.196
# 2                                      -77.1956
# 3                                      -77.1962
# 4                                      -77.1957
# ...                                         ...
# 19274                                  -16.3463
# 19275                                   47.5121
# 19276                                   121.413
# 19277                                  -15.8784
# 19278                                   99.8951
#
# [16883 rows x 38 columns]

# %% [markdown]
# # Event Photo Downloading Script
#
# The following script downloads photos associated with possible mosquito mapper training events (identified in the previous script) in addition to other information to help a human identify later identify which groups were truly training events. This can also aid in future research exploring these training events.
#
# The procedure is as follows:
# - It gets the identified training events from the previous script
# - It generates a CSV of these events for future reference
# - For each group, it creates a subfolder and proceeds to do the following:
#     - Download all the photos collected in the suspected group
#     - Create a CSV containing all the photo file names, urls, and attributions
#     - Create a CSV containing all the entries for that group

# %%
# identify groups
suspect_groups = suspect_df.groupby(by = ['measuredDate','latitude','mosquitohabitatmapperWaterSource','siteName','longitude'])

# %%
# create a groups dataset
groups_list = []
groups_data = pd.DataFrame()
for group, df in suspect_groups:
    groups_list.append(str(group))
    new_df = df.copy(True)
    new_df["Group Name"] = str(group)
    groups_data = groups_data.append(new_df, ignore_index = True)
groups_df= pd.DataFrame(groups_list, columns=["Group"])
groups_data.to_csv("Group Data.csv")
groups_df
# Out:
#                                                  Group
# 0    ('2018-07-30', 7.812627, 'other', '47NPJ040637...
# 1    ('2018-08-07', 7.812627, 'other', '47NPJ040637...
# 2    ('2018-08-14', 7.812627, 'other', '47NPJ040637...
# 3    ('2018-08-17', 8.643, 'pond', '47PNK988555', 9...
# 4    ('2018-09-01', 0.304885, 'cement, metal or pla...
# ..                                                 ...
# 112  ('2020-01-27', 15.037919, 'cement, metal or pl...
# 113  ('2020-01-27', 18.01673, 'well or cistern', '4...
# 114  ('2020-02-20', 15.040585, 'cement, metal or pl...
# 115  ('2020-03-04', 8.643917, 'cement, metal or pla...
# 116  ('2020-05-30', 15.077131, 'cement, metal or pl...
#
# [117 rows x 1 columns]

# %%
import os
# makes a results directory if it doesn't already exist
if not os.path.isdir("Results"):
        os.mkdir("Results")
        
# write the groups data to a csv
groups_df.to_csv("Results/groups.csv")

# %%
import re
def download_picture(url, directory):
    def get_picture(file_name):
        downloaded_obj = requests.get(url, allow_redirects=True)
        parent_dir = os.path.join(directory, file_name)
        with open(parent_dir, "wb") as file:
            file.write(downloaded_obj.content)

    if "https://" in url:
        photo_id = re.search(r'(?<=\d\d\d\d\/\d\d\/\d\d\/).*(?=\/)', url).group(0)
        file_name = f"{photo_id}.jpg".replace(":","-")
        get_picture(file_name)
        temp_dict = {
                        "image_name" : [file_name],
                        "origin" : "GLOBE",
                        "link" : [url],
                        "attribution" : "GLOBE",
                        "license" : "Creative Commons - share adapt attribute"
                    }
        return pd.DataFrame.from_dict(temp_dict)

# %%
# photodownloading script for suspect groups
for data, group in suspect_groups:
    pics = pd.DataFrame()
    name = f"{data[0]}-{data[2]}-{data[3]}".replace("/", "-")
    dir_name = f"Results/{name}"
    if not os.path.isdir(dir_name):
        os.mkdir(dir_name)
    group_water_source = group["mosquitohabitatmapperWaterSourcePhotoUrls"].dropna().tolist()
    group_abdomen = group["mosquitohabitatmapperAbdomenCloseupPhotoUrls"].dropna().tolist()
    group_larvae = group["mosquitohabitatmapperLarvaFullBodyPhotoUrls"].dropna().tolist()
    group_urls = group_water_source + group_abdomen + group_larvae
    for urls in group_urls:
        if urls:
            urls = urls.split(";")
            for url in urls:
                pics = pics.append(download_picture(url, dir_name), ignore_index = True)
                
    pics.to_csv(f"{dir_name}/pictures.csv")
    group.to_csv(f"{dir_name}/data.csv")

# %%
if not os.path.isdir("Clean Data"):
    os.mkdir("Clean Data")
        
# photodownloading script for clean data download
pics = pd.DataFrame()
water_source = clean_df["mosquitohabitatmapperWaterSourcePhotoUrls"].dropna().tolist()
abdomen = clean_df["mosquitohabitatmapperAbdomenCloseupPhotoUrls"].dropna().tolist()
larvae = clean_df["mosquitohabitatmapperLarvaFullBodyPhotoUrls"].dropna().tolist()
url_list = water_source + abdomen + larvae
for urls in url_list:
    if urls:
        urls = urls.split(";")
        for url in urls:
            pics = pics.append(download_picture(url, "Clean Data"), ignore_index = True)
                
pics.to_csv(f"Clean Data/pictures.csv")
